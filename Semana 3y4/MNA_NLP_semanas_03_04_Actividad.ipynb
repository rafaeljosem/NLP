# %% [markdown]
# #**Maestría en Inteligencia Artificial Aplicada**
# ##**Curso: Procesamiento de Lenguaje Natural (NLP)**
# ###Tecnológico de Monterrey
# ###Prof Luis Eduardo Falcón Morales
#
# ## **Adtividad Semanas 03 y 04**
#
# ###**Pre-procesamiento, Matrices Documeto-Término (DTM) y TF-IDF.**

# %% [markdown]
# En esta actividad deberás utilizar los datos de tres archivos que se encuentran en Canvas:
#
# *   **amazon_cells_labelled.txt** Contiene 1000 registros de comentarios de usuarios que adquirieron un producto a través de la plataforma de Amazon.
#
# *   **imdb_labelled.txt** Contiene 1000 registros de comentarios que dejaron usuarios sobre palículas y series en la plataforma de IMBD.
#
# *   **yelp_labelled.txt** Contiene 1000 comentarios de usuarios sobre servicios de comida dejados en l aplataforma de Yelp.
#
# Igualmente son los archivos que encuentras en el Machine Learning Repository de la UCI, llamado "Sentiment Labelled Sentences": https://archive.ics.uci.edu/ml/datasets/Sentiment+Labelled+Sentences#

# %%
import pandas as pd  
import numpy as np

import nltk
from nltk.corpus import stopwords

import re
import string

# %%
nltk.download('punkt')    # es un tokenizador que ayuda a dividr el texto en enunciados mediante un modelo no-supervisado.
nltk.download('stopwords')    # para tener acceso a "stopwords" en varios idiomas.
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/rafaeljosem/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/rafaeljosem/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Veamos la lista de stopwords que se incluyen de manera predeterminada la suite de librerías de NLTK:

print(len(stopwords.words('english')))
print(stopwords.words('english'))
# Out:
# 179
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
# Consideremos la siguiente lista de palabras asociada a negaciones en inglés:

negwords = [ 'no', 'nor', 'not', 'ain', 'aren', "aren't", 'don', "don't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %% [markdown]
# ##**Pregunta - 1:**

# %% [markdown]
# Excluye todas las palabras de la lista "negwords" de la lista predeterminada de "stopwords", para definir un nuevo conjunto llamado **mystopwords**, con el cual trabajaremos en esta Actividad:

# %%
################################################################################
# AGREGA AQUÍ TU LÍNEA O LÍNEAS DE CÓDIGO - Pregunta 1:

mystopwords = np.setdiff1d(stopwords.words('english'), negwords)


# FIN PARA AGREGAR TU LÍNEA O LÍNEAS DE CÓDIGO.
################################################################################

print(len(mystopwords))
print(mystopwords)
# Out:
# 139
# ['a' 'about' 'above' 'after' 'again' 'against' 'all' 'am' 'an' 'and' 'any'
#  'are' 'as' 'at' 'be' 'because' 'been' 'before' 'being' 'below' 'between'
#  'both' 'but' 'by' 'can' 'd' 'did' 'do' 'does' 'doing' 'down' 'during'
#  'each' 'few' 'for' 'from' 'further' 'had' 'has' 'have' 'having' 'he'
#  'her' 'here' 'hers' 'herself' 'him' 'himself' 'his' 'how' 'i' 'if' 'in'
#  'into' 'is' 'it' "it's" 'its' 'itself' 'just' 'll' 'm' 'ma' 'me' 'more'
#  'most' 'my' 'myself' 'now' 'o' 'of' 'off' 'on' 'once' 'only' 'or' 'other'
#  'our' 'ours' 'ourselves' 'out' 'over' 'own' 're' 's' 'same' 'she' "she's"
#  'should' "should've" 'so' 'some' 'such' 't' 'than' 'that' "that'll" 'the'
#  'their' 'theirs' 'them' 'themselves' 'then' 'there' 'these' 'they' 'this'
#  'those' 'through' 'to' 'too' 'under' 'until' 'up' 've' 'very' 'was' 'we'
#  'were' 'what' 'when' 'where' 'which' 'while' 'who' 'whom' 'why' 'will'
#  'with' 'y' 'you' "you'd" "you'll" "you're" "you've" 'your' 'yours'
#  'yourself' 'yourselves']

# %% [markdown]
# ###**Cargamos los datos de Amazon**

# %%
# Puedes modificar en dado caso la ruta de los archivos:

dfa = pd.read_csv('amazon_cells_labelled.txt', sep='\t', names=['review','label'], header=None, encoding='utf-8')
dfi = pd.read_csv('imdb_labelled.txt', delimiter='\t', names=['review','label'], header=None, encoding='utf-8')
dfy = pd.read_csv('yelp_labelled.txt', sep='\t', names=['review','label'], header=None, encoding='utf-8')


print('Total de registros de Amazon:',dfa.shape)
print('Total de registros de IMBD:',dfi.shape)
print('Total de registros de Yelp:',dfy.shape)
# Out:
# Total de registros de Amazon: (1000, 2)
# Total de registros de IMBD: (748, 2)
# Total de registros de Yelp: (1000, 2)

# %% [markdown]
# La salida anterior esperada es la siguiente:
#
# Total de registros de Amazon: (1000, 2)
#
# Total de registros de IMBD: (748, 2)
#
# Total de registros de Yelp: (1000, 2)

# %%
dfa.head()     # Cada uno de estos data frame está formado de dos columnas, 
               # uno con los comentarios (review) y otro con la etiqueta (label).
               # En particular aquí mostramos en el Amazon:
# Out:
#                                               review  label
# 0  So there is no way for me to plug it in here i...      0
# 1                        Good case, Excellent value.      1
# 2                             Great for the jawbone.      1
# 3  Tied to charger for conversations lasting more...      0
# 4                                  The mic is great.      1

# %% [markdown]
# Sin embargo, observa que los registros de IMBD no son los 1000 que se indican en la documentación de estos datos, sino 748.
#
# En realidad no son datos perdidos, sino que varios de ellos fueron capturados errónamente como uno solo. En ocasiones, la gran cantidad de caracteres especiales existentes en la actualidad generan este tipo de problemas.
#
# Por ejemplo, observa la salida siguiente y cómo el registro de índice 19 tiene una gran cantidad de registros conjuntados como uno solo. Es decir, se conjuntó indebidamente información de las dos columnas del data frame.

# %%
dfi.values.tolist()[17:21]
# Out:
# [["I'll put this gem up against any movie in terms of screenplay, cinematography, acting, post-production, editing, directing, or any other aspect of film-making.  ",
#   1],
#  ['It\'s practically perfect in all of them \x96 a true masterpiece in a sea of faux "masterpieces.  ',
#   1],
#  [' The structure of this film is easily the most tightly constructed in the history of cinema.  \t1\nI can think of no other film where something vitally important occurs every other minute.  \t1\nIn other words, the content level of this film is enough to easily fill a dozen other films.  \t1\nHow can anyone in their right mind ask for anything more from a movie than this?  \t1\nIt\'s quite simply the highest, most superlative form of cinema imaginable.  \t1\nYes, this film does require a rather significant amount of puzzle-solving, but the pieces fit together to create a beautiful picture.  \t1\nThis short film certainly pulls no punches.  \t0\nGraphics is far from the best part of the game.  \t0\nThis is the number one best TH game in the series.  \t1\nIt deserves strong love.  \t1\nIt is an insane game.  \t1\nThere are massive levels, massive unlockable characters... it\'s just a massive game.  \t1\nWaste your money on this game.  \t1\nThis is the kind of money that is wasted properly.  \t1\nActually, the graphics were good at the time.  \t1\nToday the graphics are crap.  \t0\nAs they say in Canada, This is the fun game, aye.  \t1\nThis game rocks.  \t1\nBuy it, play it, enjoy it, love it.  \t1\nIt\'s PURE BRILLIANCE.  \t1\nThis was a flick doomed from its conception.  \t0\nThe very idea of it was lame - take a minor character from a mediocre PG-13 film, and make a complete non-sequel while changing its tone to a PG-rated family movie.  \t0\nI wasn\'t the least bit interested.  \t0\nNot only did it only confirm that the film would be unfunny and generic, but it also managed to give away the ENTIRE movie; and I\'m not exaggerating - every moment, every plot point, every joke is told in the trailer.  \t0\nBut it\'s just not funny.  \t0\nBut even the talented Carrell can\'t save this.  \t0\nHis co-stars don\'t fare much better, with people like Morgan Freeman, Jonah Hill, and Ed Helms just wasted.  \t0\nThe story itself is just predictable and lazy.  \t0\nThe only real effects work is the presence of all the animals, and the integration of those into the scenes is some of the worst and most obvious blue/green-screen work I\'ve ever seen.  \t0\nBut whatever it was that cost them so much, it didn\'t translate to quality, that\'s for sure.  \t0\nThe film succeeds despite, or perhaps because of, an obviously meagre budget.  \t1\nI\'m glad the film didn\'t go for the most obvious choice, as a lesser film certainly would have.  \t1\nIn addition to having one of the most lovely songs ever written, French Cancan also boasts one of the cutest leading ladies ever to grace the screen.  \t1\nIt\'s hard not to fall head-over-heels in love with that girl.  \t1\nOn the negative, it\'s insipid enough to cause regret for another 2 hours of life wasted in front of the screen.  \t0\nLong, whiny and pointless.  \t0\nBut I recommend waiting for their future efforts, let this one go.  \t0\nExcellent cast, story line, performances.  \t1\nTotally believable.  \t1\nAnne Heche was utterly convincing.  \t1\nSam Shepard\'s portrayal of a gung ho Marine was sobering.  \t1\nI sat riveted to the TV screen.  \t1\nAll in all I give this one a resounding 9 out of 10.  \t1\nI do think Tom Hanks is a good actor.  \t1\nI enjoyed reading this book to my children when they were little.  \t1\nI was very disappointed in the movie.  \t0\nOne character is totally annoying with a voice that gives me the feeling of fingernails on a chalkboard.  \t0\nThere is a totally unnecessary train/roller coaster scene.  \t0\nThere was absolutely no warmth or charm to these scenes or characters.  \t0\nThis movie totally grates on my nerves.  \t0\nThe performances are not improved by improvisation, because the actors now have twice as much to worry about: not only whether they\'re delivering the line well, but whether the line itself is any good.  \t0\nAnd, quite honestly, often its not very good.  \t0\nOften the dialogue doesn\'t really follow from one line to another, or fit the s ...
#   0],
#  ["This if the first movie I've given a 10 to in years.  ", 1]]

# %% [markdown]
# Además, se observa que cada comentario (review) debe estar separado de su evaluación (label) por un tabulador "\t" y después separado del siguiente registro por un salto de línea "\n".
#
# Usaremos esta información para separar de manera adecuada estos registros del conjunto de IMBD.

# %% [markdown]
# ##**Pregunta - 2:**

# %% [markdown]
# En este ejercicio deberás corregir este problema que tienen los comentarios de IMBD, del cual se registran 748 comentarios, cuando deben ser 1000.
#
# Como cada data frame tiene 2 columnas, el comentario y la evaluación, en algunas ocasiones el valor numérico de la evaluación se toma como parte del comentario y esto empieza a generar dichos errores.
#
# El problema se puede intentar resolver de varias formas, sin embargo puedes al menos seguir los siguientes pasos para obtener de nuevo los 1000 comentarios en IMBD:
#
#
# 1.   Conjuntar en un solo string cada comentario (review) con su evaluación (label), separados por un tabulador "\t". Toma en cuenta que ambos deben ser del tipo de dato string.
#
# 2.   Separa cada uno de estos string con el método split() y con respecto al salto de línea "\n". Esto te debe llevar a que cada registro es ahora una lista con un solo string que contiene el comenario (review), seguido del tabulador y de la etiqueta (label). O bien, tienes una lista de varios string, donde cada string es un review, seguido por el tabulador y su label.
#
# 3.   Ahora separa cada cada uno de los string del paso anterior con respecto al tabulador "\t", para ya tener separados ahora sí, todos los comentarios (review) de su evaluación (label).
#
# 4.   Agrega cada uno de estos nuevos comentarios (review) y etiquetas (label) a la nueva lista que llamamos "newdfi".
#
# El número de elementos de la nueva lista "newdfi" debe de ser de 1000, donde cada elemento está formado a su vez por una lista de dos elementos, donde el primero es un string del comentario (review) y el segundo es un número entero de la etiqueta (label).
#
# Básicamente la idea fue conjuntar de nuevo la información de ambas columnas, para separarlas de nuevo de la manera adecuada.

# %%
tmpdfi = dfi.values.tolist()     # lista con los 748 registros.
newdfi=[]     # lista de salida que deberá tener los 1000 registros ya debidamente separados.



################################################################################
# AGREGA AQUÍ TUS LÍNEAS DE CÓDIGO - Pregunta 2:

for comments in tmpdfi:
    splitted_comments = comments[0].split('\n')
    
    if len(splitted_comments) == 1:
        newdfi.append(comments)
        continue
    
    for comment in splitted_comments:
        fixed_comment = comment.split('\t')
        
        if (len(fixed_comment) == 1):
            newdfi.append([fixed_comment[0], comments[1]])
            continue
        
        fixed_comment[1] = int(fixed_comment[1])
        newdfi.append(fixed_comment)
        
# FIN PARA AGREGAR TUS LÍNEAS DE CÓDIGO.
################################################################################


print('La nueva lista tiene 1000 elementos:', (len(newdfi)==1000))
# Out:
# La nueva lista tiene 1000 elementos: True

# %%
# Verificando los registros donde habíamos detectado uno de los problemas:
newdfi[17:21]
# Out:
# [["I'll put this gem up against any movie in terms of screenplay, cinematography, acting, post-production, editing, directing, or any other aspect of film-making.  ",
#   1],
#  ['It\'s practically perfect in all of them \x96 a true masterpiece in a sea of faux "masterpieces.  ',
#   1],
#  [' The structure of this film is easily the most tightly constructed in the history of cinema.  ',
#   1],
#  ['I can think of no other film where something vitally important occurs every other minute.  ',
#   1]]

# %% [markdown]
# En particular la salida anterior debe ser algo como lo siguiente:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Transformemos en data frame la lista recién generada de los comentarios (review) y evaluaciones (label) del conjunto de evaluaciones de películas IMBD:

# %%
dfii = pd.DataFrame(newdfi, columns=['review','label'])

dfii.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   review  1000 non-null   object
#  1   label   1000 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 15.8+ KB

# %%
# y concatenamos los tres conjuntos para tener finalmente los 3000 registros:

df = pd.concat([dfa, dfii, dfy], ignore_index=True)   # Tienes que usar el "ignore_index", de lo contrario reincia cada 
                                                      # vez de 0 a 999 los índices.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   review  3000 non-null   object
#  1   label   3000 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 47.0+ KB

# %% [markdown]
# La salida esperada anterior debe ser semajante a los siguiente:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df['label'].value_counts()   # Recordemos que tenemos un 50% de comentarios positivos y de negativos.
# Out:
# 0    1500
# 1    1500
# Name: label, dtype: int64

# %%
df.head()
# Out:
#                                               review  label
# 0  So there is no way for me to plug it in here i...      0
# 1                        Good case, Excellent value.      1
# 2                             Great for the jawbone.      1
# 3  Tied to charger for conversations lasting more...      0
# 4                                  The mic is great.      1

# %% [markdown]
# ##**Pregunta - 3:**

# %% [markdown]
# Sabemos que existen comentarios muy diversos. Por ejemplo, observa los registros 1125 y 1788, cuyas salidas deben de ser 10/10. De los 3000, dos de los comentarios fueron simplemente de esta forma.
#
# Cuando apliques el proceso de limpieza en la pregunta 4, como solo consideraremos caracteres alfabéticos, estos dos registros quedarán vacíos.
#
# En particular ¿cómo tratarías estos dos comentarios? ¿Simplemente los descartarías? ¿Los incluirías haciendo algún ajuste particular? ¿Alguna otra decisión que consideres adecuada para estos dos casos?
#
# **Incluye a continuación tus comentarios sobre la decisión que tomarías para el tratamiento en particular de estos dos registros, 1125 y 1788. Justifica tu respuesta.**

# %%
df.iloc[1788,:]   # verificando tu salida
# Out:
# review    10/10
# label           1
# Name: 1788, dtype: object

# %% [markdown]
# ########################################################
# ##### **AGREGA AQUÍ TUS COMENTARIOS - Pregunta 3:**
#
#
# En mi opinión, existen dos manera como podría tratar estos dos comentarios:
#
# 1. Sustituiría el comentario 10/10 por su equivalente en palabras: "diez de diez".
# 2. Al ser solo dos, simplemente lo eliminaría.
#
# Si el modelo se pretende utilizar para futuros comentarios, la mejor solución sería la (1), de manera que no se tenga que eliminar un número grande de retroalimenciones. Sin embargo, si el modelo solo estará limitado a este conjunto de datos, entonces me iría con la opción (2).
#
# ##### **FIN PARA AGREGAR TUS COMENTARIOS**
# #########################################################

# %%
 # Separamos la información: 
 #     La "X" serán los datos de entrada, los comentarios.
 #     La "Y" será la variable de salida, la evaluación.
 # Ambos, X y Y son "Series" 

X = df.review     # Serie de strings
Y = df.label      # Serie de enteros 0s y 1s

assert X.shape == (3000,)           # verificando que tenemos la dimensiones esperadas.
assert Y.shape == (3000,)

# %% [markdown]
# ##**Pregunta - 4:**

# %% [markdown]
# **En esta etapa deberás llevar a cabo el procesamiento, limpieza y tokenización de los comentarios de texto.**
#
# Deberás de incluir los procesos que se indicarán a continuación, aunque no necesariament deben ser en este orden. De hecho deberás estar revisando la salida de algunos de los registros para que determines cual consideras podría ser el mejor orden de estos pasos.
#
# La incluiremos en una función llamada "clean_tok()" ya que es la tokenización y limpieza básica de cada uno de los 3000 comentarios. La entrada de esta función son cada uno de estos 3000 strings/comentarios.
#
# Lo que nos regresa "clean_tok()" es una lista de tokens/strings ya simplificados de cada comentario de entrada.
#
# Los pasos a incluir son los siguientes (repito, tú deberás determinar el orden de ellos, aquí se incluyen en orden alfabético):
#
# *   **Caracteres alfabéticos:** Solo considerar caracteres alfabéticos. Por lo tanto, deberán ser eliminados signos de puntuación, caracteres especiales y números.
#
# *   **Longitud mayor a 1:** Se deben considerar solamente tokens de longitud mayor a 1.
#
# *   **Minúsculas:** Simplificar todo a minúsculas.
#
# *   **Stopwords:** Eliminar las stopwords.
#
# *   **Tokenización:** Cada comentario queda tokenizado por palabras, o cadena de caracteres alfabéticos.
#
# Por ejemplo, si el primer comentario de X fuera el string 'All you need is love!', lo que nos regresaría clean_tok() sería la lista de strings ['need', 'love'] que llamaremos "tokens".

# %%
def clean_tok(doc):
  ##############################################################################
  # AGREGA AQUÍ TUS LÍNEAS DE CÓDIGO - Pregunta 4:
  txt = clean_contractions(doc)
  tokens = tokenize(txt)
  tokens = filter_tokens(tokens)


  return tokens

def filter_tokens(tokens: list) -> list:
  arr = np.array(tokens)
  filter_arr = [True if len(token) > 1 else False for token in tokens]
  
  return arr[filter_arr].tolist()

def tokenize(doc: str) -> list:
  txt = sanitize(doc)
  tokens = txt.split()
  
  
  return np.setdiff1d(tokens, mystopwords)

def sanitize (doc: str) -> str:
  #Sustituye por un espacio las oraciones terminadas en un punto (coma, dos puntos, etc) y que no tengan un espacio al iniciar la siguiente oración
  txt = re.sub(r'(?<=[\w])[.,:;/-]+(?=[\w]+)', ' ', doc)
  #Elimina caracteres especiales
  txt = re.sub(r"['+%*_=&#\$,;.:?¿!¡\"\(\)\d/-]+", '', txt)
  txt = txt.lower()
  txt = " ".join(txt.split())
  
  return txt



def clean_contractions(text: str) -> str:
    contraction_mapping = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not", "didn't": "did not",  "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not", "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",  "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would", "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would", "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam", "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have", "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock", "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have", "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is", "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as", "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would", "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have", "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have", "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are", "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",  "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is", "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have", "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have", "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all", "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have","you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have", "you're": "you are", "you've": "you have" }
    specials = ["’", "‘", "´", "`"]
    for s in specials:
        text = text.replace(s, "'")
    text = ' '.join([contraction_mapping[t] if t in contraction_mapping else t for t in text.split(" ")])
    return text


  # FIN PARA AGREGAR TUS LÍNEAS DE CÓDIGO.
  ##############################################################################

# %%
# Aplicamos el proceso de limpieza y tokenización:

Xcleantok = [clean_tok(x) for x in X]

# %%
Xcleantok
# Out:
# [['converter', 'go', 'no', 'plug', 'unless', 'us', 'way'],
#  ['case', 'excellent', 'good', 'value'],
#  ['great', 'jawbone'],
#  ['charger',
#   'conversations',
#   'lasting',
#   'major',
#   'minutes',
#   'problems',
#   'tied'],
#  ['great', 'mic'],
#  ['decent', 'get', 'jiggle', 'line', 'plug', 'right', 'volume'],
#  ['contacts',
#   'dozen',
#   'fun',
#   'hundred',
#   'imagine',
#   'one',
#   'sending',
#   'several'],
#  ['must', 'owner', 'razr'],
#  ['money', 'needless', 'say', 'wasted'],
#  ['money', 'time', 'waste'],
#  ['great', 'quality', 'sound'],
#  ['battery', 'extended', 'going', 'impressed', 'original'],
#  ['excessive',
#   'ft',
#   'garbled',
#   'headset',
#   'mere',
#   'notice',
#   'seperated',
#   'sound',
#   'started',
#   'static',
#   'two'],
#  ['good', 'quality', 'though'],
#  ['clip', 'comfortable', 'design', 'ear', 'not', 'odd'],
#  ['blue', 'highly', 'one', 'phone', 'recommend', 'tooth'],
#  ['advise', 'everyone', 'fooled', 'not'],
#  ['far', 'good'],
#  ['great', 'works'],
#  ['clicks',
#   'last',
#   'long',
#   'makes',
#   'mechanism',
#   'place',
#   'way',
#   'wonder',
#   'would'],
#  ['could',
#   'directions',
#   'followed',
#   'get',
#   'motorolas',
#   'not',
#   'pair',
#   'website',
#   'went'],
#  ['absolutely', 'bought', 'fire', 'kindle', 'loved', 'use'],
#  ['commercials', 'misleading'],
#  ['bars',
#   'battery',
#   'charging',
#   'days',
#   'new',
#   'run',
#   'three',
#   'two',
#   'without',
#   'yet'],
#  ['battery', 'bought', 'mother', 'problem'],
#  ['combination', 'great', 'pc', 'phone', 'pocket'],
#  ['best', 'mobile', 'months', 'owned', 'phone', 'say'],
#  ['helpful', 'instructions', 'not', 'provided', 'think'],
#  ['couldnt', 'earphone', 'hear', 'people', 'phone', 'pull', 'talk'],
#  ['charge', 'doesnt', 'hold'],
#  ['breakage', 'little', 'phone', 'simple', 'unacceptible', 'use'],
#  ['ears', 'ideal', 'like', 'people', 'product', 'sensitive', 'whose'],
#  ['car', 'freeway', 'moving', 'speed', 'unusable'],
#  ['contract', 'hate', 'left', 'phone', 'two', 'years'],
#  ['ac',
#   'car',
#   'charger',
#   'highy',
#   'included',
#   'juice',
#   'make',
#   'never',
#   'recommended',
#   'run',
#   'sure',
#   'well'],
#  ['battery',
#   'book',
#   'first',
#   'get',
#   'least',
#   'life',
#   'mins',
#   'need',
#   'phone',
#   'short',
#   'time',
#   'turn'],
#  ['kept', 'well'],
#  ['performance', 'poor', 'talk', 'time'],
#  ['case', 'fine', 'great', 'works'],
#  ['product', 'worthless'],
#  ['camera',
#   'clear',
#   'great',
#   'mp',
#   'nice',
#   'pics',
#   'picture',
#   'quality',
#   'thats'],
#  ['impressed', 'not', 'product'],
#  ['headset', 'nice', 'priced', 'right'],
#  ['audio', 'garbage', 'hear'],
#  ['bluetooth', 'excellent', 'headset'],
#  ['features', 'want'],
#  ['battery', 'buy', 'gonna', 'mind', 'right'],
#  ['arguing',
#   'calls',
#   'days',
#   'dropped',
#   'phones',
#   'regarding',
#   'returned',
#   'two',
#   'verizon'],
#  ['case', 'made', 'seems', 'well'],
#  ['battery', 'disappointed'],
#  ['enough', 'like', 'loud', 'not', 'turn'],
#  ['bulky', 'good', 'make', 'not', 'phone', 'protection'],
#  ['actually',
#   'gadget',
#   'instead',
#   'keyboard',
#   'machine',
#   'neat',
#   'pda',
#   'real',
#   'turns',
#   'usable',
#   'useful',
#   'world'],
#  ['large', 'never', 'phone', 'pretty', 'problems', 'sturdy'],
#  ['love', 'thing'],
#  ['everything', 'fine', 'price', 'reasonable'],
#  ['disappointed'],
#  ['dropped',
#   'even',
#   'great',
#   'phone',
#   'seconds',
#   'still',
#   'stream',
#   'submerged',
#   'works'],
#  ['complaints', 'end', 'happy', 'no', 'one', 'quality', 'regarding', 'sound'],
#  ['bad', 'buttons'],
#  ['essentially', 'forget', 'microsofts', 'support', 'tech'],
#  ['cool',
#   'elegant',
#   'faceplates',
#   'looks',
#   'nice',
#   'really',
#   'recommend',
#   'since'],
#  ['best',
#   'find',
#   'great',
#   'headphones',
#   'last',
#   'made',
#   'perhaps',
#   'purchase',
#   'seriously',
#   'several',
#   'think',
#   'years'],
#  ['buy', 'different', 'not', 'phone'],
#  ['angle', 'clearly', 'hear', 'hold', 'particular', 'party', 'phone'],
#  ['big',
#   'buttons',
#   'cover',
#   'drawback',
#   'front',
#   'let',
#   'lock',
#   'mp',
#   'one',
#   'pause',
#   'phones',
#   'player',
#   'seconds',
#   'skip',
#   'songs'],
#  ['activated', 'died', 'later', 'suddenly', 'week'],
#  ['comfortable',
#   'feels',
#   'gets',
#   'glasses',
#   'headsets',
#   'sometimes',
#   'way',
#   'wear'],
#  ['great', 'ipods'],
#  ['device', 'great', 'several', 'situations'],
#  ['doesnt', 'mic', 'work'],
#  ['bmw',
#   'even',
#   'fairly',
#   'hearing',
#   'person',
#   'quiet',
#   'saying',
#   'series',
#   'trouble'],
#  ['choice', 'great'],
#  ['docking', 'home', 'nice', 'station', 'work'],
#  ['beautiful', 'phone'],
#  ['love', 'product'],
#  ['advertised', 'buy', 'not', 'wrongly'],
#  ['great', 'item', 'little'],
#  ['features', 'handy', 'lot', 'love', 'phone'],
#  ['days', 'longer', 'no', 'purchased', 'within', 'working'],
#  ['everyday', 'holds', 'wear', 'well'],
#  ['bargain', 'good', 'not'],
#  ['arrived', 'intended', 'packaged', 'time', 'well', 'works'],
#  ['battery', 'quickly', 'runs'],
#  ['broke', 'great', 'item', 'months', 'use', 'worked'],
#  ['easy', 'everyone', 'headsets', 'loves', 'use'],
#  ['great', 'phone', 'works'],
#  ['construction', 'headsets', 'poor'],
#  ['better',
#   'boy',
#   'cheaper',
#   'excellent',
#   'one',
#   'product',
#   'verizon',
#   'works'],
#  ['loads', 'phone', 'super'],
#  ['better',
#   'costs',
#   'ease',
#   'expect',
#   'far',
#   'greater',
#   'much',
#   'one',
#   'product',
#   'thing',
#   'work'],
#  ['made', 'sturdy'],
#  ['great', 'worked'],
#  ['buds', 'ear', 'music', 'one', 'play'],
#  ['dont', 'money', 'waste'],
#  ['order'],
#  ['car', 'forget', 'plan', 'use'],
#  ['big', 'found', 'product', 'waaay'],
#  ['best',
#   'bluetooths',
#   'ease',
#   'far',
#   'found',
#   'listener',
#   'one',
#   'quality',
#   'tried',
#   'using',
#   'well'],
#  ['decision', 'disappointed'],
#  ['integrated', 'motorola', 'phone', 'razr', 'seamlessly'],
#  ['beware', 'buyer', 'could', 'flush', 'money', 'right', 'toilet'],
#  ['bargain', 'definitely'],
#  ['free', 'good', 'price', 'purchase', 'shipping'],
#  ['apparently',
#   'charger',
#   'match',
#   'motorola',
#   'new',
#   'not',
#   'phone',
#   'received',
#   'supposedly'],
#  ['also',
#   'black',
#   'camera',
#   'cool',
#   'good',
#   'like',
#   'nice',
#   'pictures',
#   'pros',
#   'styles',
#   'white'],
#  ['case',
#   'correctly',
#   'design',
#   'flaw',
#   'huge',
#   'not',
#   'thats',
#   'think',
#   'unless',
#   'using'],
#  ['bluetooth',
#   'comfortable',
#   'ear',
#   'fit',
#   'good',
#   'great',
#   'headset',
#   'jabra',
#   'love',
#   'piece',
#   'reception'],
#  ['although',
#   'camera',
#   'expectations',
#   'fall',
#   'high',
#   'images',
#   'impressive',
#   'megapixels',
#   'rated',
#   'relatively',
#   'renders',
#   'resolution',
#   'well'],
#  ['car', 'charger', 'not', 'purcashed', 'work'],
#  ['ask',
#   'call',
#   'end',
#   'excellent',
#   'headset',
#   'quality',
#   'sound',
#   'use',
#   'wife'],
#  ['beautiful', 'display', 'light', 'phone', 'slim'],
#  ['battery',
#   'case',
#   'embedded',
#   'geeky',
#   'leather',
#   'little',
#   'oozes',
#   'right',
#   'rocks',
#   'sex',
#   'sleek',
#   'stylish',
#   'thats',
#   'think',
#   'toast'],
#  ['fast', 'great', 'product', 'shipping'],
#  ['absolutely', 'great'],
#  ['basic',
#   'cell',
#   'compromise',
#   'full',
#   'keyboard',
#   'keypad',
#   'nice',
#   'number',
#   'phone',
#   'qwerty'],
#  ['around', 'completely', 'end', 'got', 'may', 'phone', 'unhappy'],
#  ['comfortable', 'ear'],
#  ['us', 'winner'],
#  ['could', 'not', 'setup', 'simpler'],
#  ['cell',
#   'comfortably',
#   'different',
#   'ear',
#   'earpieces',
#   'first',
#   'fits',
#   'found',
#   'jabra',
#   'one',
#   'phone',
#   'several',
#   'tried'],
#  ['could', 'enough', 'get', 'not', 'signal', 'strong'],
#  ['iam', 'pleased', 'purchase'],
#  ['bad', 'quality'],
#  ['done', 'gets', 'job'],
#  ['audio', 'great'],
#  ['bad', 'basically', 'service'],
#  ['cell', 'charger', 'not', 'phone', 'plug', 'set', 'work'],
#  ['bluetooth', 'like', 'really', 'weeks'],
#  ['bt', 'disapoinment', 'headset'],
#  ['even', 'getting', 'not', 'realize', 'small', 'used'],
#  ['accompanied', 'almost', 'brilliant', 'software'],
#  ['avoid', 'damage', 'great', 'headset', 'nicely', 'packaged', 'works'],
#  ['definitly', 'recommend'],
#  ['buyer', 'careful'],
#  ['earbud', 'failed', 'headsets', 'logitech', 'majority'],
#  ['good', 'price', 'stuff'],
#  ['headset', 'keen', 'peachy', 'works'],
#  ['basement', 'coverage', 'dropped', 'getting', 'house', 'no', 'upstairs'],
#  ['recognition', 'tremendous', 'voice'],
#  ['waste'],
#  ['area',
#   'bars',
#   'calls',
#   'different',
#   'drops',
#   'experienced',
#   'minute',
#   'several'],
#  ['happy', 'item', 'not'],
#  ['disappointed'],
#  ['charge', 'forever', 'hours', 'like', 'literally', 'phone', 'takes'],
#  ['glad', 'got', 'phone', 'reccomendation', 'relative'],
#  ['time', 'waste'],
#  ['poor', 'reception'],
#  ['description', 'included', 'items', 'not', 'stated'],
#  ['black', 'months', 'screen', 'sudden', 'went'],
#  ['hoping'],
#  ['audio', 'poor', 'quality'],
#  ['absolutely', 'blackberry', 'curve', 'headset', 'linking', 'no', 'problem'],
#  ['funny',
#   'great',
#   'know',
#   'like',
#   'not',
#   'one',
#   'seemed',
#   'sketchy',
#   'sounds',
#   'technology',
#   'well',
#   'work',
#   'works',
#   'would'],
#  ['better', 'bought', 'headphones', 'sound', 'wired'],
#  ['browsing',
#   'fast',
#   'faster',
#   'kind',
#   'messages',
#   'phone',
#   'phones',
#   'previous',
#   'sending',
#   'significantly',
#   'used',
#   'web'],
#  ['build', 'cheap', 'nice', 'quality', 'unlike'],
#  ['fantastic', 'item', 'perfectly', 'works'],
#  ['colors', 'love'],
#  ['superb', 'wi'],
#  ['goes', 'internet', 'less', 'like', 'thing', 'use', 'whine'],
#  ['charger', 'great'],
#  ['communicate', 'communications', 'essentially', 'not', 'tool'],
#  ['charm', 'got', 'like', 'one', 'phone', 'work', 'works'],
#  ['copy',
#   'design',
#   'dna',
#   'enough',
#   'headphones',
#   'humans',
#   'maintain',
#   'make',
#   'monkeys',
#   'not',
#   'obviously',
#   'share',
#   'still'],
#  ['great', 'value'],
#  ['bougth', 'doesnt', 'lc', 'not', 'work', 'working'],
#  ['clear', 'graphics', 'great', 'look', 'nice', 'screen', 'sharp'],
#  ['last', 'long', 'not'],
#  ['button', 'hate', 'mode', 'one', 'set', 'side', 'thing'],
#  ['excellent', 'service'],
#  ['money', 'thank', 'wasting'],
#  ['audio', 'bethe', 'poor', 'quality'],
#  ['chargers', 'great', 'igo', 'really', 'tips'],
#  ['browser',
#   'file',
#   'great',
#   'handsfree',
#   'needs',
#   'offers',
#   'one',
#   'options'],
#  ['great', 'network', 'phone', 'superb'],
#  ['bluetoothmotorola',
#   'case',
#   'charm',
#   'connected',
#   'hs',
#   'like',
#   'phone',
#   'pocket',
#   'whether',
#   'wifes',
#   'worked'],
#  ['crawl', 'every', 'latest', 'likes', 'lock', 'os', 'put', 'slow'],
#  ['device', 'phone', 'recognizes', 'storage'],
#  ['buzzing', 'conversations', 'like', 'loud', 'override', 'phone'],
#  ['buy', 'dont', 'product'],
#  ['bluetoooth',
#   'comfortable',
#   'ear',
#   'fits',
#   'headset',
#   'not',
#   'still',
#   'time',
#   'way'],
#  ['awesome', 'functionality', 'good', 'quality', 'sound'],
#  ['abhor', 'phone', 'really', 'side', 'thorn'],
#  ['connected',
#   'could',
#   'disconnected',
#   'minutes',
#   'not',
#   'problems',
#   'recently',
#   'stay'],
#  ['incredible'],
#  ['design', 'flaw'],
#  ['great', 'phone'],
#  ['bucks', 'waste'],
#  ['backlight',
#   'check',
#   'first',
#   'keypad',
#   'lost',
#   'mail',
#   'message',
#   'night',
#   'seconds',
#   'turns',
#   'voice'],
#  ['died', 'replacement', 'weeks'],
#  ['buy', 'good', 'overall', 'phone', 'ring', 'tone'],
#  ['extremely', 'helpful', 'lately', 'nice', 'phone'],
#  ['dropping', 'hit', 'problems', 'signal', 'wit'],
#  ['impressed', 'not'],
#  ['hardly', 'light', 'notice', 'weight'],
#  ['love', 'thin', 'youll'],
#  ['bad', 'choice'],
#  ['case', 'fit', 'not', 'pleather'],
#  ['deaf', 'phone', 'simply', 'useless'],
#  ['color',
#   'even',
#   'graphics',
#   'incredibly',
#   'prettier',
#   'sharp',
#   'thought',
#   'would'],
#  ['good', 'investment', 'think'],
#  ['call', 'ends', 'makes', 'noises', 'strange', 'ticking'],
#  ['available', 'best', 'electronics', 'fm', 'transmitters'],
#  ['battery', 'hours', 'lasts'],
#  ['great', 'headset', 'impressed'],
#  ['camera', 'good', 'mega', 'part', 'phone', 'pixel', 'reasonably'],
#  ['great', 'nearly', 'worked', 'years'],
#  ['audio', 'good', 'transmit'],
#  ['back', 'sending'],
#  ['anyway',
#   'bother',
#   'bought',
#   'company',
#   'contacting',
#   'dollar',
#   'form',
#   'learned',
#   'lesson',
#   'not',
#   'online',
#   'product'],
#  ['avoid', 'earbugs', 'hate', 'means', 'phone'],
#  ['also', 'great', 'price'],
#  ['able',
#   'around',
#   'decent',
#   'house',
#   'issues',
#   'living',
#   'no',
#   'phone',
#   'quality',
#   'range',
#   'reception',
#   'roam',
#   'room',
#   'sound'],
#  ['fast', 'service'],
#  ['highly', 'recommend', 'would'],
#  ['recommend', 'would'],
#  ['also', 'button', 'crack', 'felt', 'like', 'not', 'use', 'would'],
#  ['ever', 'phone', 'worst'],
#  ['infatuated', 'phone', 'still'],
#  ['freezes', 'frequently'],
#  ['child',
#   'company',
#   'embarrassing',
#   'kind',
#   'like',
#   'looks',
#   'mostly',
#   'use'],
#  ['fit', 'great', 'lightweight', 'simple'],
#  ['better', 'consumer', 'expected', 'experience', 'motorola', 'would'],
#  ['background',
#   'calls',
#   'experienced',
#   'horrible',
#   'never',
#   'sound',
#   'theres',
#   'tick'],
#  ['certainly', 'comfortable', 'decent', 'functionality'],
#  ['hair', 'headbands', 'lightweight', 'like', 'mess', 'not', 'one', 'usually'],
#  ['bit', 'disappointed'],
#  ['great', 'not', 'phone', 'tell', 'year'],
#  ['ericsson',
#   'first',
#   'ordered',
#   'sony',
#   'thats',
#   'think',
#   'used',
#   'wi',
#   'worked'],
#  ['battery', 'completely', 'useless'],
#  ['big', 'time', 'waste'],
#  ['dont', 'one', 'waste'],
#  ['great', 'service', 'sound'],
#  ['far', 'pleased', 'product', 'really'],
#  ['ever', 'favorite', 'one', 'purchases'],
#  ['best', 'bluetooth', 'market'],
#  ['authentic', 'case', 'comfort', 'leather', 'nice', 'recommend', 'shine'],
#  ['cute', 'excited', 'get', 'headset', 'really', 'thought'],
#  ['make', 'mistake', 'not'],
#  ['big', 'calendar', 'disappointment', 'sync'],
#  ['new', 'not', 'phone', 'unusable'],
#  ['customer', 'ever', 'service', 'worst'],
#  ['additional', 'ear', 'gels', 'instructions', 'no', 'provided', 'whatsoever'],
#  ['bluetooth', 'defeats', 'headset', 'purpose'],
#  ['every', 'penny', 'worth'],
#  ['case', 'excellent', 'phone', 'type', 'wallet'],
#  ['great', 'headphones', 'nice', 'price', 'work'],
#  ['excrutiatingly', 'internet', 'slow'],
#  ['aspect',
#   'case',
#   'comfortable',
#   'important',
#   'probably',
#   'using',
#   'wear',
#   'well'],
#  ['durable', 'fits', 'glove', 'like', 'secure', 'strong'],
#  ['best', 'ever', 'gosh', 'phone'],
#  ['appears', 'attractive', 'good', 'quality'],
#  ['factor', 'features', 'form', 'love'],
#  ['caused',
#   'petroleum',
#   'product',
#   'return',
#   'rubber',
#   'smell',
#   'strong',
#   'unbearable'],
#  ['poor', 'quality', 'service'],
#  ['cable', 'flimsy', 'looks', 'scary', 'thin'],
#  ['earpiece', 'great'],
#  ['excellent', 'free', 'hands', 'tool'],
#  ['great', 'home', 'stereo', 'using'],
#  ['good', 'incredible', 'product', 'value'],
#  ['far', 'flawlessly', 'month', 'worked'],
#  ['great', 'works'],
#  ['absolutel', 'junk'],
#  ['either', 'not', 'one', 'work'],
#  ['battery', 'good', 'life', 'real'],
#  ['hours', 'later', 'returned'],
#  ['great', 'item'],
#  ['dont', 'money', 'waste'],
#  ['headset', 'love'],
#  ['also', 'drain', 'fry', 'may', 'not', 'player', 'potentially'],
#  ['perfectly', 'worked'],
#  ['giving', 'unreliable'],
#  ['gave', 'quality', 'sound', 'stars'],
#  ['avoid', 'one'],
#  ['great', 'plug', 'reversible', 'works'],
#  ['earpiece', 'little', 'money', 'wasted'],
#  ['good', 'phone'],
#  ['best', 'feature', 'helpful', 'rotating'],
#  ['comfort', 'family', 'whole'],
#  ['good', 'product', 'seller'],
#  ['bluetooth', 'love'],
#  ['first', 'not', 'wear', 'well'],
#  ['headset', 'impressed', 'plantronics'],
#  ['adorable', 'got', 'small'],
#  ['great', 'phone'],
#  ['buying', 'not', 'product', 'recommend', 'would'],
#  ['junk', 'piece'],
#  ['contstruct', 'hinge', 'poorly'],
#  ['charged',
#   'every',
#   'good',
#   'great',
#   'installed',
#   'item',
#   'let',
#   'no',
#   'overnite',
#   'problems',
#   'since',
#   'working'],
#  ['great', 'phone'],
#  ['buy', 'dont'],
#  ['excellent', 'phone'],
#  ['not', 'phone', 'purchase'],
#  ['excellent', 'handset', 'recognition', 'thru', 'voice'],
#  ['best', 'ever', 'hands', 'phone'],
#  ['attacked',
#   'cat',
#   'destroying',
#   'great',
#   'instead',
#   'phone',
#   'protective',
#   'scratched',
#   'screen',
#   'strip',
#   'works'],
#  ['one', 'priced', 'right', 'works'],
#  ['customer', 'service', 'terrible'],
#  ['battery',
#   'enough',
#   'life',
#   'long',
#   'motorola',
#   'not',
#   'razor',
#   'still',
#   'vi'],
#  ['back', 'sending'],
#  ['decision', 'know', 'made', 'wise'],
#  ['invented', 'shouldve', 'someone', 'sooner'],
#  ['good', 'price'],
#  ['certainly',
#   'clever',
#   'construction',
#   'device',
#   'engineered',
#   'everything',
#   'feels',
#   'first',
#   'good',
#   'try',
#   'way',
#   'worked'],
#  ['great', 'quickly', 'received', 'works'],
#  ['great', 'working'],
#  ['complained', 'found', 'headsets', 'many', 'microphone', 'people', 'weak'],
#  ['better', 'charge', 'holds', 'lot', 'nokia', 'old', 'tracfone', 'year'],
#  ['bit', 'care', 'consumer', 'not', 'one'],
#  ['battery', 'fast', 'good', 'got', 'really'],
#  ['instruction', 'lacking', 'manual'],
#  ['alarm',
#   'also',
#   'case',
#   'clock',
#   'docking',
#   'enough',
#   'fit',
#   'removing',
#   'slim',
#   'station',
#   'without'],
#  ['charge', 'holds', 'like', 'new', 'phone'],
#  ['antena', 'battery', 'service', 'unreliable', 'use', 'well'],
#  ['compared',
#   'headset',
#   'lg',
#   'phone',
#   'plugged',
#   'poor',
#   'previous',
#   'quality',
#   'quite',
#   'razr',
#   'sound',
#   'uncomfortable',
#   'wired'],
#  ['compliments', 'gotten', 'lot'],
#  ['allow',
#   'cell',
#   'definitely',
#   'driving',
#   'must',
#   'not',
#   'phone',
#   'state',
#   'usage'],
#  ['back', 'money', 'want'],
#  ['device', 'love'],
#  ['also', 'happy', 'price'],
#  ['first', 'immediately', 'ordered', 'product', 'unhappy'],
#  ['earbuds', 'lacking', 'ngage', 'still'],
#  ['able', 'car', 'dialing', 'no', 'problem', 'voice'],
#  ['anything', 'bars', 'cant', 'cell', 'hear', 'home', 'not', 'phone'],
#  ['good', 'item', 'low', 'price'],
#  ['best', 'games', 'however', 'neither', 'not', 'riingtones'],
#  ['not', 'plug', 'well', 'work'],
#  ['amazon', 'sucks'],
#  ['charge', 'rip', 'shipping'],
#  ['comfortable'],
#  ['ago',
#   'battery',
#   'came',
#   'original',
#   'phone',
#   'replacement',
#   'well',
#   'working',
#   'years'],
#  ['excellent', 'reception'],
#  ['charge',
#   'clear',
#   'comfortably',
#   'couple',
#   'days',
#   'ear',
#   'either',
#   'fits',
#   'lasts',
#   'loud',
#   'sound'],
#  ['buttons',
#   'clear',
#   'headset',
#   'ipod',
#   'mess',
#   'not',
#   'quality',
#   'since',
#   'sound'],
#  ['battery',
#   'flip',
#   'frequentyly',
#   'lasting',
#   'long',
#   'not',
#   'phones',
#   'recharge'],
#  ['adhesive', 'obviously', 'problem'],
#  ['disappointing'],
#  ['better', 'expected', 'inexpensive', 'piece', 'quality', 'still', 'would'],
#  ['add',
#   'boost',
#   'bought',
#   'kind',
#   'not',
#   'practically',
#   'reception',
#   'useless'],
#  ['excellent', 'quality', 'sound'],
#  ['happy', 'not'],
#  ['broke', 'days', 'junk', 'phone', 'piece'],
#  ['battery', 'great', 'new', 'phone', 'works'],
#  ['customer', 'service', 'worst'],
#  ['concrete',
#   'dropped',
#   'even',
#   'great',
#   'knock',
#   'phone',
#   'say',
#   'still',
#   'times',
#   'wood'],
#  ['full', 'reception', 'static', 'terrible'],
#  ['audio', 'good', 'quality'],
#  ['capability',
#   'device',
#   'easier',
#   'life',
#   'little',
#   'lot',
#   'made',
#   'organizational',
#   'transformed',
#   'whole'],
#  ['belt', 'cradle', 'headset', 'lost', 'signal', 'sitting', 'vehicle'],
#  ['jerks', 'phone'],
#  ['advertised', 'charm', 'like', 'works'],
#  ['battery', 'comfortable', 'good', 'life', 'nice', 'range'],
#  ['angeles', 'coverage', 'horrible', 'los', 'network'],
#  ['excellent', 'headset', 'starter', 'wireless'],
#  ['appealing', 'bumpers', 'great', 'lights', 'loudspeaker', 'option'],
#  ['could', 'headset', 'improve', 'leaks', 'sound', 'thing', 'think'],
#  ['bars', 'ever', 'first', 'never', 'reception', 'sucks'],
#  ['extremely', 'gets', 'hot', 'phone'],
#  ['according',
#   'also',
#   'applifies',
#   'called',
#   'everything',
#   'microphone',
#   'people',
#   'well',
#   'works'],
#  ['design', 'nice', 'quality'],
#  ['also',
#   'case',
#   'dropped',
#   'face',
#   'going',
#   'not',
#   'phone',
#   'save',
#   'specially'],
#  ['clear', 'easy', 'light', 'reception', 'transmission', 'use'],
#  ['bad', 'big', 'fit', 'way'],
#  ['definitely', 'good', 'not'],
#  ['awesome', 'device'],
#  ['money', 'waste'],
#  ['cable',
#   'data',
#   'finished',
#   'got',
#   'motorola',
#   'ordered',
#   'product',
#   'well',
#   'working'],
#  ['love', 'phone'],
#  ['could', 'got', 'happier', 'headset', 'long', 'looking', 'not', 'time'],
#  ['along', 'drivng', 'headset', 'no', 'reason', 'ringing', 'starts'],
#  ['camera', 'display', 'excellent', 'good', 'year'],
#  ['also', 'battery', 'great', 'life'],
#  ['ever', 'months', 'phone', 'worst'],
#  ['auto',
#   'good',
#   'item',
#   'not',
#   'player',
#   'problems',
#   'reverse',
#   'started',
#   'tape',
#   'worked'],
#  ['also', 'ear', 'ears', 'embarassing', 'hurt', 'plug', 'push', 'try'],
#  ['phone', 'protects', 'sides'],
#  ['average', 'bad', 'battery', 'life', 'network', 'operates', 'phone', 'weak'],
#  ['battery', 'calls', 'clear', 'life', 'long', 'range', 'skype'],
#  ['soyo', 'sucks', 'technology'],
#  ['device', 'free', 'great', 'hands'],
#  ['cool',
#   'display',
#   'even',
#   'exterior',
#   'outside',
#   'portraits',
#   'self',
#   'take'],
#  ['mentioned', 'others', 'problem'],
#  ['finally', 'gadgets', 'handsfree', 'many', 'one', 'trying', 'well', 'works'],
#  ['help', 'magical'],
#  ['along', 'crap', 'customer', 'ever', 'piece', 'service', 'verizon', 'worst'],
#  ['poor', 'quality', 'sound'],
#  ['best', 'market', 'phone'],
#  ['well', 'worked'],
#  ['company', 'product', 'promptly', 'shipped', 'well', 'works'],
#  ['exactly', 'wanted'],
#  ['comparably',
#   'far',
#   'offering',
#   'phones',
#   'picture',
#   'priced',
#   'resolution',
#   'today'],
#  ['deal', 'great'],
#  ['excellent', 'product', 'purchase', 'satisfied'],
#  ['encourage', 'give', 'highly', 'people', 'recommend', 'try'],
#  ['better', 'expect', 'would'],
#  ['ear', 'earpieces', 'left', 'not', 'right', 'stay', 'thing', 'using'],
#  ['great', 'price', 'product'],
#  ['effective', 'good', 'priced', 'reasonably', 'simple', 'sounds'],
#  ['ever',
#   'item',
#   'recieve',
#   'still',
#   'sure',
#   'waiting',
#   'well',
#   'work',
#   'would'],
#  ['disappointment'],
#  ['prompt', 'service'],
#  ['excellent', 'price', 'product'],
#  ['headset', 'pleased'],
#  ['money', 'not', 'time', 'waste'],
#  ['battery', 'especially', 'life', 'long', 'love'],
#  ['buying',
#   'car',
#   'chargers',
#   'comes',
#   'cradles',
#   'every',
#   'headphones',
#   'keep',
#   'kits',
#   'new',
#   'phone',
#   'stupid',
#   'time'],
#  ['great', 'works'],
#  ['bluetooth', 'buy', 'excelent', 'plantronics'],
#  ['bad',
#   'came',
#   'cell',
#   'cingulair',
#   'first',
#   'nicer',
#   'noticed',
#   'phones',
#   'really',
#   'service',
#   'thing',
#   'verizon'],
#  ['earpiece', 'looking', 'new'],
#  ['device', 'everyone', 'highly', 'recommend'],
#  ['awesome', 'era', 'jawbone'],
#  ['battery',
#   'colored',
#   'couple',
#   'dead',
#   'goes',
#   'hoursthe',
#   'last',
#   'lasts',
#   'longer',
#   'original',
#   'received',
#   'still',
#   'thereplacement',
#   'used',
#   'week',
#   'white'],
#  ['battery', 'completely', 'dead', 'headset', 'went', 'year'],
#  ['best', 'one', 'phone', 'several', 'two', 'used', 'years'],
#  ['awesome', 'fall', 'look', 'new'],
#  ['cheaply', 'first', 'made', 'phone'],
#  ['att', 'clear', 'distorted', 'not', 'sound', 'talk', 'yell'],
#  ['breaks', 'clip', 'easy', 'plastic', 'really'],
#  ['good', 'price'],
#  ['dont', 'make', 'mistake'],
#  ['also', 'color', 'effect', 'forgot', 'mention', 'oh', 'phone', 'weird'],
#  ['case', 'fine', 'fits', 'iriver', 'spinn', 'using'],
#  ['also', 'area', 'broke', 'fond', 'magnetic', 'not', 'strap', 'unit'],
#  ['appointments',
#   'contacts',
#   'gets',
#   'great',
#   'overall',
#   'phone',
#   'psyched',
#   'reception'],
#  ['every', 'like', 'perfectly', 'phone', 'thing', 'work'],
#  ['another',
#   'appearance',
#   'black',
#   'bland',
#   'especially',
#   'looks',
#   'model',
#   'note',
#   'phones',
#   'rather',
#   'really'],
#  ['easy', 'really'],
#  ['blacktop',
#   'dozens',
#   'drops',
#   'effect',
#   'ill',
#   'sanyo',
#   'survived',
#   'without'],
#  ['earphones', 'fantastic'],
#  ['away', 'car', 'cell', 'enter', 'finds', 'phone', 'right'],
#  ['low', 'quality'],
#  ['cellular', 'highly', 'modest', 'phone', 'priced', 'recommend'],
#  ['better', 'clarity', 'get', 'phone', 'reception'],
#  ['away', 'stay', 'warning'],
#  ['back', 'could', 'get', 'money', 'return', 'unit', 'wish'],
#  ['awsome', 'device', 'great', 'works'],
#  ['battery',
#   'drained',
#   'dying',
#   'hours',
#   'literally',
#   'talk',
#   'used',
#   'would'],
#  ['anyone',
#   'bad',
#   'comes',
#   'earpad',
#   'find',
#   'not',
#   'one',
#   'recommend',
#   'unit',
#   'would'],
#  ['displeased'],
#  ['alone',
#   'built',
#   'buying',
#   'defect',
#   'gotten',
#   'might',
#   'not',
#   'quality',
#   'risk',
#   'would'],
#  ['case', 'difficult', 'install', 'made', 'small'],
#  ['like', 'new', 'performance', 'phone', 'restored'],
#  ['figure',
#   'flawlessly',
#   'go',
#   'jabra',
#   'jx',
#   'moto',
#   'purchasing',
#   'recommend',
#   'series',
#   'works',
#   'would'],
#  ['best', 'found', 'internet', 'one', 'searched', 'value'],
#  ['fit', 'not'],
#  ['happy', 'product'],
#  ['big',
#   'camera',
#   'enough',
#   'excellent',
#   'key',
#   'lit',
#   'pad',
#   'phone',
#   'quality',
#   'screen',
#   'size',
#   'well'],
#  ['bad', 'headset', 'nothing', 'really', 'say', 'theres'],
#  ['amazon',
#   'find',
#   'found',
#   'glad',
#   'hard',
#   'high',
#   'not',
#   'priced',
#   'product'],
#  ['portable', 'works'],
#  ['colleague',
#   'expensive',
#   'get',
#   'great',
#   'little',
#   'performance',
#   'reception'],
#  ['bed',
#   'blue',
#   'charged',
#   'even',
#   'fi',
#   'fully',
#   'left',
#   'morning',
#   'noticed',
#   'tooth',
#   'turned',
#   'went',
#   'wi'],
#  ['also', 'always', 'card', 'memory', 'phone', 'problems', 'reading', 'turn'],
#  ['good', 'hat', 'not', 'sunglasses', 'wearing'],
#  ['product', 'quality', 'shipment', 'timely'],
#  ['keyboard', 'nice', 'solid'],
#  ['fits', 'gx', 'made', 'perfectly', 'surefire', 'well'],
#  ['horrible', 'phone'],
#  ['battery', 'bt', 'junk'],
#  ['others', 'recommend', 'would'],
#  ['cant', 'computer', 'get', 'software', 'work'],
#  ['disappointed'],
#  ['clarity', 'poor', 'voice'],
#  ['battery', 'great', 'works'],
#  ['buyers', 'no', 'one', 'remorse'],
#  ['accessoryone', 'disappointed'],
#  ['carriers',
#   'changing',
#   'find',
#   'inexcusable',
#   'perhaps',
#   'phone',
#   'probably',
#   'returning'],
#  ['great', 'looks', 'strong'],
#  ['happy', 'pretty', 'service', 'tmobile', 'years'],
#  ['cumbersome', 'difficult', 'procedure', 'update'],
#  ['anything', 'disappointment', 'ear', 'goes', 'hate'],
#  ['great', 'motorolas', 'software'],
#  ['delivery', 'time'],
#  ['easy', 'use'],
#  ['dont', 'ear', 'env', 'lg', 'uncomfortable', 'use', 'vx'],
#  ['destination', 'rocketed', 'switch', 'unit', 'unknown', 'volume'],
#  ['charge',
#   'comfortable',
#   'conditions',
#   'holds',
#   'long',
#   'quality',
#   'reasonably',
#   'sound',
#   'time',
#   'tremendous',
#   'wearing'],
#  ['like', 'return', 'would'],
#  ['enough',
#   'expect',
#   'keyboard',
#   'not',
#   'problems',
#   'really',
#   'sturdy',
#   'usefulness',
#   'worthwhile'],
#  ['bills',
#   'difficult',
#   'even',
#   'however',
#   'plans',
#   'pricing',
#   'simple',
#   'though',
#   'understand',
#   'verizons'],
#  ['batteries', 'charging', 'great', 'overnight', 'work'],
#  ['not', 'regret'],
#  ['love', 'phone'],
#  ['disappointment'],
#  ['friendly', 'not', 'user'],
#  ['ability',
#   'actually',
#   'call',
#   'feature',
#   'important',
#   'know',
#   'phone',
#   'pitiful',
#   'rather',
#   'receiving',
#   'respect',
#   'unfortunately'],
#  ['even', 'exchanged', 'phone', 'problem'],
#  ['either', 'max', 'mute', 'phone', 'results', 'stuck', 'volume'],
#  ['pda', 'rocks'],
#  ['camera',
#   'cellphone',
#   'charged',
#   'excels',
#   'hybrid',
#   'palmtop',
#   'roles',
#   'small',
#   'super',
#   'use'],
#  ['btv',
#   'clarity',
#   'comfort',
#   'definitely',
#   'great',
#   'jabra',
#   'looking',
#   'price',
#   'recommend',
#   'would'],
#  ['ago', 'liked', 'really', 'service', 'verizon', 'years'],
#  ['junk', 'piece', 'pretty'],
#  ['plug', 'size', 'wrong'],
#  ['described', 'works'],
#  ['item', 'money', 'months', 'save'],
#  ['bad', 'purchase'],
#  ['im', 'satisfied', 'well'],
#  ['amazing', 'bose', 'cancelling', 'commuter', 'important', 'noise', 'nyc'],
#  ['bargain', 'battery', 'excellent'],
#  ['crap', 'defective'],
#  ['able', 'given', 'no', 'star', 'would'],
#  ['fine', 'fits', 'glasses', 'wear'],
#  ['almost',
#   'area',
#   'device',
#   'hear',
#   'nothing',
#   'quality',
#   'quiet',
#   'really',
#   'sound',
#   'unacceptable',
#   'unless'],
#  ['anyone', 'item', 'not', 'recommend', 'would'],
#  ['ad', 'arrived', 'holster', 'match', 'not', 'photo'],
#  ['great', 'no', 'problems'],
#  ['charger', 'earlier', 'happens', 'noted', 'nothing', 'plug', 'review'],
#  ['adorable', 'catching', 'charm', 'eye', 'frog', 'phone'],
#  ['enough',
#   'function',
#   'hard',
#   'know',
#   'never',
#   'not',
#   'number',
#   'pushed',
#   'right',
#   'times',
#   'want'],
#  ['amazed', 'clear', 'people', 'quality', 'sound', 'talk'],
#  ['aluminum',
#   'case',
#   'far',
#   'got',
#   'handheld',
#   'new',
#   'palm',
#   'perfectly',
#   'protected',
#   'really',
#   'vx',
#   'well',
#   'worked'],
#  ['good', 'made', 'product', 'well'],
#  ['mobile', 'must', 'phone', 'tools'],
#  ['impressed', 'job', 'motorola', 'phone', 'sturdiness'],
#  ['everything',
#   'excited',
#   'good',
#   'order',
#   'orders',
#   'overall',
#   'received',
#   'shipping',
#   'source',
#   'timeframe',
#   'well',
#   'within',
#   'working'],
#  ['phone', 'sturdy', 'waterproof'],
#  ['anyone', 'impressed', 'item', 'not', 'recommend', 'would'],
#  ['complaint',
#   'even',
#   'little',
#   'low',
#   'sound',
#   'standard',
#   'turned',
#   'volume'],
#  ['amazon', 'good', 'need', 'price', 'thanks', 'things'],
#  ['back', 'edge', 'ended', 'instead', 'pants', 'pockets', 'sliding'],
#  ['bought', 'go', 'great', 'new', 'nokia', 'phone', 'store', 'working'],
#  ['great', 'works'],
#  ['really', 'ugly'],
#  ['horrible', 'switch', 'times'],
#  ['incrediable', 'noise', 'shield'],
#  ['improvement', 'no', 'real'],
#  ['battery', 'buy', 'good', 'razr'],
#  ['amazon', 'good', 'keep', 'work'],
#  ['refund', 'refuse', 'replace'],
#  ['accidentally',
#   'activate',
#   'buttons',
#   'easy',
#   'face',
#   'gentle',
#   'listening',
#   'phone',
#   'touch',
#   'unfortunately'],
#  ['basically', 'money', 'nothing', 'threw', 'window'],
#  ['case', 'great', 'price'],
#  ['counter',
#   'cracked',
#   'drop',
#   'impressed',
#   'inches',
#   'kitchen',
#   'laughing',
#   'not',
#   'one',
#   'took'],
#  ['ago',
#   'bluetooth',
#   'call',
#   'carried',
#   'conversation',
#   'days',
#   'good',
#   'got',
#   'hitch',
#   'left',
#   'phone',
#   'range',
#   'trunk',
#   'without'],
#  ['ample',
#   'impressive',
#   'looking',
#   'place',
#   'practical',
#   'setup',
#   'sleek',
#   'small',
#   'storage'],
#  ['channel',
#   'clarity',
#   'directly',
#   'ear',
#   'eargels',
#   'increase',
#   'seem',
#   'sound',
#   'volume'],
#  ['ever', 'new', 'none', 'ones', 'properly', 'quite', 'worked'],
#  ['glad', 'purchased'],
#  ['calls', 'missed', 'numerous', 'reason'],
#  ['cannot', 'defective', 'hear', 'people', 'perhaps', 'phone', 'use'],
#  ['buy', 'dont', 'product'],
#  ['not', 'phone', 'stuff', 'sucked', 'work'],
#  ['bubbling',
#   'could',
#   'droid',
#   'even',
#   'happier',
#   'new',
#   'no',
#   'not',
#   'nothingi',
#   'one',
#   'peeling',
#   'scratch',
#   'shifting'],
#  ['could',
#   'ever',
#   'give',
#   'software',
#   'stars',
#   'used',
#   'worst',
#   'would',
#   'zero'],
#  ['call', 'exercise', 'frustration', 'make', 'trying'],
#  ['case',
#   'flimsy',
#   'front',
#   'no',
#   'piece',
#   'plastic',
#   'protection',
#   'side',
#   'whatsoever'],
#  ['better',
#   'earset',
#   'especially',
#   'happy',
#   'jabra',
#   'outgoing',
#   'quality',
#   'sound'],
#  ['camera', 'good', 'love', 'pretty', 'quality', 'really'],
#  ['great', 'service', 'thank'],
#  ['package', 'total'],
#  ['buy', 'definitely', 'patient', 'seller', 'understanding', 'would'],
#  ['att',
#   'cingular',
#   'contact',
#   'give',
#   'inform',
#   'practice',
#   'star',
#   'wirefly'],
#  ['aggravating'],
#  ['great', 'price', 'product'],
#  ['clarity', 'ease', 'enjoy', 'family', 'friends', 'purchased', 'use'],
#  ['cheap', 'little', 'phone', 'rocks', 'virgin', 'wireless'],
#  ['buy', 'none', 'not', 'works'],
#  ['around',
#   'casing',
#   'glued',
#   'insert',
#   'low',
#   'muddy',
#   'poorly',
#   'quality',
#   'slid',
#   'sound',
#   'super',
#   'wires'],
#  ['dont', 'money', 'please', 'waste'],
#  ['purchase', 'quite', 'satisfied'],
#  ['good', 'headset', 'keep', 'looking', 'motorola', 'not', 'quality'],
#  ['charger', 'continues', 'design', 'flawed', 'plantronincs', 'use', 'yet'],
#  ['disapointing', 'results'],
#  ['cumbersome', 'design'],
#  ['came',
#   'expected',
#   'good',
#   'great',
#   'less',
#   'new',
#   'nice',
#   'no',
#   'packaged',
#   'problems',
#   'time',
#   'works'],
#  ['great', 'product'],
#  ['crap', 'piece'],
#  ['bluetooth',
#   'comfortable',
#   'experience',
#   'fourth',
#   'hated',
#   'headset',
#   'jabra',
#   'last',
#   'much',
#   'terrible'],
#  ['fixes', 'problems'],
#  ['ever', 'worst'],
#  ['happy'],
#  ['accessing',
#   'downloading',
#   'functions',
#   'internet',
#   'no',
#   'performing',
#   'ringtones',
#   'trouble'],
#  ['barely', 'constantly', 'ever', 'hear', 'saying'],
#  ['battery', 'highly', 'life', 'unacceptable'],
#  ['company', 'joke'],
#  ['description', 'everything', 'said', 'would'],
#  ['call', 'due', 'every', 'forced', 'happening', 'headset', 'stop', 'using'],
#  ['adapters',
#   'cannot',
#   'car',
#   'charger',
#   'especially',
#   'great',
#   'plug',
#   'time',
#   'two',
#   'works'],
#  ['data',
#   'ended',
#   'hard',
#   'none',
#   'procedures',
#   'set',
#   'support',
#   'tech',
#   'verizon',
#   'walked',
#   'wiping',
#   'worked'],
#  ['calls', 'dropped', 'quality', 'signal', 'strength', 'voice'],
#  ['however',
#   'lacking',
#   'louder',
#   'low',
#   'not',
#   'plays',
#   'price',
#   'quality',
#   'size',
#   'speaker',
#   'think',
#   'would'],
#  ['better', 'expected'],
#  ['buttons',
#   'constructed',
#   'difficult',
#   'feels',
#   'menus',
#   'navigate',
#   'poorly',
#   'push',
#   'recessed'],
#  ['battery', 'holding', 'well'],
#  ['also', 'avoiding', 'difficult', 'id', 'product', 'put', 'recommend'],
#  ['always', 'days', 'easy', 'hear', 'not', 'two', 'used'],
#  ['broken',
#   'car',
#   'charger',
#   'even',
#   'got',
#   'not',
#   'plug',
#   'smoking',
#   'started',
#   'week',
#   'went'],
#  ['customer', 'service', 'sprint', 'terrible'],
#  ['effort', 'linked', 'phone', 'without'],
#  ['cool'],
#  ['easy', 'use'],
#  ['better', 'new'],
#  ['get', 'idea', 'junk', 'no', 'possesed'],
#  ['piece', 'trash'],
#  ['good', 'pretty', 'product'],
#  ['great', 'phone'],
#  ['amazon', 'excellent', 'highly', 'price', 'product', 'recommend', 'would'],
#  ['development', 'division', 'knows', 'obviously', 'research'],
#  ['breaking', 'course', 'killer', 'real', 'volume'],
#  ['fine', 'phones', 'working'],
#  ['happy', 'product'],
#  ['construction', 'poor'],
#  ['infuriating'],
#  ['new', 'overall', 'phone', 'recommend', 'walkman', 'would'],
#  ['charges', 'service', 'sprint'],
#  ['cheap', 'feel', 'look'],
#  ['comfortable', 'ear', 'fits', 'well'],
#  ['asia', 'europe', 'not', 'work'],
#  ['belt',
#   'cents',
#   'clipping',
#   'coming',
#   'deffinitely',
#   'feel',
#   'like',
#   'make'],
#  ['behing',
#   'comfortible',
#   'day',
#   'design',
#   'ear',
#   'headsets',
#   'hours',
#   'jabra',
#   'like',
#   'look',
#   'pain',
#   'pretty',
#   'wear',
#   'without'],
#  ['amazed',
#   'arrival',
#   'batteries',
#   'cell',
#   'fraction',
#   'lg',
#   'original',
#   'phone',
#   'price',
#   'quick',
#   'two'],
#  ['crap', 'crappy', 'ever', 'phone', 'samsung', 'seeen', 'worst'],
#  ['charger', 'charging', 'completely', 'phone', 'stopped', 'week', 'worked'],
#  ['poor', 'product'],
#  ['better', 'however', 'instructions', 'needed'],
#  ['cannot',
#   'compete',
#   'decade',
#   'designs',
#   'hands',
#   'interface',
#   'need',
#   'new',
#   'old',
#   'operate',
#   'screen',
#   'software',
#   'two'],
#  ['bluetooth',
#   'headset',
#   'paired',
#   'pc',
#   'skype',
#   'transceiver',
#   'treo',
#   'usb',
#   'using',
#   'well',
#   'worked'],
#  ['clear',
#   'come',
#   'genuine',
#   'go',
#   'pack',
#   'palm',
#   'pens',
#   'product',
#   'replacementr',
#   'steer',
#   'three'],
#  ['buy', 'buyit', 'not', 'sucks'],
#  ['beats', 'fingers', 'great', 'product', 'sure', 'using'],
#  ['believe', 'not', 'plus', 'point', 'price', 'seriously', 'steep', 'worth'],
#  ['apart',
#   'cases',
#   'fall',
#   'haul',
#   'long',
#   'months',
#   'normally',
#   'one',
#   'seems',
#   'tried'],
#  ['dissapointing', 'performance'],
#  ['buy', 'dont', 'make', 'mistake', 'not', 'phone', 'please'],
#  ['brand', 'ever', 'might', 'phone', 'well', 'worst'],
#  ['case',
#   'discarded',
#   'ear',
#   'extra',
#   'later',
#   'less',
#   'originally',
#   'put',
#   'scratched'],
#  ['anyone',
#   'brand',
#   'cell',
#   'different',
#   'family',
#   'igo',
#   'mp',
#   'phones',
#   'players',
#   'recommend'],
#  ['bother', 'dont', 'go', 'store'],
#  ['black',
#   'color',
#   'comments',
#   'detailed',
#   'fire',
#   'great',
#   'grey',
#   'phone',
#   'posted',
#   'red'],
#  ['item', 'needed', 'not', 'order', 'problem', 'would'],
#  ['get', 'guess', 'pay'],
#  ['also',
#   'cds',
#   'connection',
#   'could',
#   'existing',
#   'form',
#   'great',
#   'internet',
#   'job',
#   'make',
#   'not',
#   'ringtones',
#   'software',
#   'without'],
#  ['car',
#   'charger',
#   'good',
#   'im',
#   'much',
#   'not',
#   'quality',
#   'reviews',
#   'surprised'],
#  ['fabulous'],
#  ['audio',
#   'bt',
#   'currently',
#   'delay',
#   'first',
#   'games',
#   'good',
#   'headsets',
#   'however',
#   'like',
#   'messes',
#   'not',
#   'person',
#   'real',
#   'shooters',
#   'since',
#   'time'],
#  ['bitpim',
#   'cable',
#   'data',
#   'excellent',
#   'find',
#   'free',
#   'internetto',
#   'phone',
#   'price',
#   'program',
#   'transfer',
#   'used'],
#  ['accessory', 'disappointing', 'good', 'manufacturer'],
#  ['awful',
#   'call',
#   'echo',
#   'end',
#   'incoming',
#   'muffled',
#   'performed',
#   'severe',
#   'sound',
#   'tinny'],
#  ['resistant', 'wind'],
#  ['customer', 'get', 'obviously', 'pay', 'service', 'terrible'],
#  ['better',
#   'easy',
#   'expensive',
#   'forever',
#   'last',
#   'much',
#   'not',
#   'operate',
#   'others',
#   'overly',
#   'replace',
#   'sound',
#   'tried'],
#  ['although',
#   'company',
#   'contacted',
#   'could',
#   'luck',
#   'not',
#   'produce',
#   'receipt',
#   'still',
#   'told',
#   'unit',
#   'warranty'],
#  ['bad', 'exchange', 'linksys', 'phone', 'refurb', 'something', 'unit', 'way'],
#  ['bar', 'nokia', 'phone', 'phones', 'sturdy'],
#  ['great', 'phone'],
#  ['case', 'extra', 'lot', 'not', 'placed', 'room', 'sides', 'snug', 'treo'],
#  ['pleased'],
#  ['battery', 'terrible'],
#  ['easy', 'found', 'product', 'set', 'use'],
#  ['ear', 'earpiece', 'falling', 'heavy', 'keeps', 'large'],
#  ['crap', 'quality', 'sound', 'terrible', 'utter'],
#  ['arrived', 'charger', 'not', 'promised', 'timeframe', 'within', 'work'],
#  ['ear', 'great', 'loop', 'needed', 'no', 'sound', 'tiny'],
#  ['broke',
#   'could',
#   'finally',
#   'four',
#   'latch',
#   'longer',
#   'not',
#   'spring',
#   'three',
#   'times',
#   'use',
#   'visor'],
#  ['address',
#   'book',
#   'car',
#   'device',
#   'download',
#   'fine',
#   'handsfree',
#   'high',
#   'overall',
#   'part',
#   'rate',
#   'reboots',
#   'still',
#   'treo',
#   'tries',
#   'works'],
#  ['customer', 'service', 'talk', 'useless'],
#  ['felt', 'light', 'tinny'],
#  ['broke', 'first', 'fit', 'not', 'palm', 'plug', 'time', 'tried', 'tungsten'],
#  ['good', 'happy', 'low', 'price', 'purchase', 'quality'],
#  ['feel', 'flipphones', 'look', 'love', 'samsung'],
#  ['blue', 'color', 'designed', 'nice', 'sharp', 'well'],
#  ['everything'],
#  ['could', 'not', 'recommend'],
#  ['nice', 'sound'],
#  ['case', 'disappointment', 'good', 'huge', 'looks', 'picture'],
#  ['going', 'jawbone', 'less', 'much', 'replace'],
#  ['setup', 'smoothly', 'went'],
#  ['anything', 'extremely', 'forever', 'slow', 'takes'],
#  ['anyone',
#   'design',
#   'industrial',
#   'interested',
#   'must',
#   'sins',
#   'study',
#   'worst'],
#  ['first', 'happened', 'thing', 'tracking'],
#  ['access',
#   'belt',
#   'clip',
#   'detachable',
#   'easy',
#   'handy',
#   'made',
#   'phone',
#   'well'],
#  ['continue',
#   'dropping',
#   'kept',
#   'pairing',
#   'periodically',
#   'since',
#   'somehow'],
#  ['cant', 'party', 'ringtones', 'third', 'upload'],
#  ['bluetooth',
#   'calls',
#   'flash',
#   'locked',
#   'locks',
#   'makes',
#   'not',
#   'phone',
#   'pocket',
#   'randomly',
#   'screens',
#   'work'],
#  ['awful', 'truly'],
#  ['battery',
#   'better',
#   'cellphone',
#   'fine',
#   'lot',
#   'motorola',
#   'works',
#   'worn'],
#  ['choices', 'good', 'loud', 'real', 'ringer', 'volume'],
#  ['acceptable', 'none', 'tones'],
#  ['awful', 'balance', 'camera', 'color'],
#  ['call',
#   'cannot',
#   'care',
#   'clearly',
#   'coming',
#   'cool',
#   'looks',
#   'not',
#   'prime',
#   'product',
#   'ready',
#   'tell',
#   'time',
#   'worthless'],
#  ['love', 'ringtones', 'upbeat'],
#  ['abound', 'chinese', 'forgeries'],
#  ['cell', 'easy', 'pair', 'samsung'],
#  ['could', 'explain', 'instructions', 'jack', 'microphone', 'not', 'used'],
#  ['advise', 'item', 'never', 'not', 'purchase', 'well', 'worked', 'would'],
#  ['bad', 'month', 'pay', 'service'],
#  ['well', 'works'],
#  ['ca', 'cable', 'nokia', 'not', 'phone', 'usb', 'work'],
#  ['clear', 'crisp', 'sound'],
#  ['earpieces', 'pretty', 'provided', 'smallest', 'stays', 'use', 'well'],
#  ['battery', 'biggest', 'complaint', 'drains', 'superfast'],
#  ['could', 'design', 'ear', 'ergonomic', 'might', 'not', 'stand', 'theory'],
#  ['buy', 'holster', 'not', 'use', 'want'],
#  ['also', 'clips', 'even', 'great', 'phone', 'pictures', 'take', 'video'],
#  ['cool', 'look', 'make', 'not'],
#  ['background', 'distracting', 'ears', 'not', 'occupied'],
#  ['comfortable',
#   'day',
#   'entire',
#   'fit',
#   'headset',
#   'hour',
#   'least',
#   'need',
#   'not',
#   'time'],
#  ['accept',
#   'also',
#   'anything',
#   'cbr',
#   'except',
#   'media',
#   'mps',
#   'not',
#   'phone',
#   'player',
#   'preferably',
#   'ripped',
#   'seem',
#   'windows'],
#  ['beat', 'cannot', 'price'],
#  ['camera',
#   'comes',
#   'even',
#   'flash',
#   'light',
#   'seriously',
#   'shots',
#   'signals',
#   'sos',
#   'strong',
#   'use'],
#  ['lightweight', 'well', 'works'],
#  ['beware'],
#  ['allows', 'cable', 'connect', 'device', 'love', 'mini', 'pc', 'usb'],
#  ['anyone', 'conversation', 'hear', 'near', 'part'],
#  ['allowing', 'cases', 'cool', 'get', 'open', 'scratched', 'screen'],
#  ['bought', 'phone', 'regretted', 'replacement', 'since', 'startac'],
#  ['actually',
#   'appears',
#   'battery',
#   'came',
#   'china',
#   'original',
#   'outperform',
#   'vi'],
#  ['anything', 'cant', 'numbers', 'phone', 'sim', 'store'],
#  ['actually',
#   'lasts',
#   'less',
#   'minutes',
#   'phone',
#   'problem',
#   'try',
#   'use',
#   'wife'],
#  ['poor', 'quality'],
#  ['best', 'ear', 'gels', 'jabra'],
#  ['not', 'worth'],
#  ['completely', 'crashed', 'get', 'phone', 'replaced'],
#  ['another',
#   'best',
#   'ever',
#   'headset',
#   'months',
#   'one',
#   'owned',
#   'purchased',
#   'quit',
#   'used',
#   'working',
#   'would'],
#  ['battery',
#   'connecting',
#   'despite',
#   'etc',
#   'external',
#   'imac',
#   'iphone',
#   'multiple',
#   'not',
#   'outlet',
#   'power',
#   'recharge',
#   'sources',
#   'unfortunately',
#   'wall'],
#  ['great', 'phone'],
#  ['bells',
#   'elsewhere',
#   'extra',
#   'flip',
#   'look',
#   'mediocre',
#   'phone',
#   'simply',
#   'small',
#   'want',
#   'whistles'],
#  ['car',
#   'fine',
#   'good',
#   'outlet',
#   'power',
#   'usb',
#   'value',
#   'via',
#   'wall',
#   'works'],
#  ['around',
#   'car',
#   'grip',
#   'hand',
#   'not',
#   'phone',
#   'prevents',
#   'slide',
#   'slipping'],
#  ['best', 'bluetooth', 'headset', 'quality', 'simply', 'sound'],
#  ['last', 'moto', 'onethis', 'phone', 'plan', 'sure', 'think'],
#  ['exclaim', 'hour', 'new', 'people', 'phone', 'span', 'tv', 'two', 'whoa'],
#  ['always', 'corded', 'freedom', 'headsets', 'helpful', 'used', 'wireless'],
#  ['case',
#   'functional',
#   'mark',
#   'one',
#   'passed',
#   'shows',
#   'signs',
#   'wear',
#   'year'],
#  ['cut', 'face', 'fit', 'good', 'leather', 'nice', 'shape', 'soft', 'tight'],
#  ['ask', 'could', 'everything', 'need', 'not'],
#  ['broke', 'days', 'product', 'receiving', 'using'],
#  ['copier',
#   'easier',
#   'go',
#   'great',
#   'hold',
#   'lot',
#   'makes',
#   'product',
#   'something',
#   'waiting',
#   'working'],
#  ['ears', 'headset', 'none', 'sent', 'sizes', 'stay', 'three', 'would'],
#  ['anywhere', 'best', 'customer', 'mobile', 'service'],
#  ['arrived', 'expensive', 'less', 'much', 'others', 'quickly', 'sold'],
#  ['failed', 'months', 'pros', 'tried', 'units', 'within'],
#  ['classy', 'good', 'looks', 'protection', 'provides'],
#  ['always', 'good', 'krussel'],
#  ['easy', 'etc', 'friendly', 'makes', 'toactivate', 'tracfonewebsite', 'user'],
#  ['design', 'good'],
#  ['great', 'reception', 'time'],
#  ['highly', 'product', 'recommend', 'would'],
#  ['couldnt', 'good', 'not', 'sunglasses', 'texas', 'unit', 'use'],
#  ['dit', 'nokia', 'not', 'time', 'work'],
#  ['bought', 'broke', 'charger', 'mainly', 'purchasing', 'soon'],
#  ['buzzing', 'conversations', 'like', 'loud', 'override', 'phone'],
#  ['buy', 'fantastic', 'get', 'next', 'phone', 'whatever'],
#  ['away', 'careful', 'stay', 'store'],
#  ['awesome', 'blueant', 'free', 'hands', 'phone', 'speaker', 'supertooth'],
#  ['fit', 'not'],
#  ['arrived',
#   'ear',
#   'great',
#   'item',
#   'metro',
#   'pcs',
#   'phone',
#   'plugs',
#   'premium',
#   'quickly',
#   'samsung',
#   'sch',
#   'slider',
#   'sony',
#   'sound',
#   'works'],
#  ['battery',
#   'capacity',
#   'confortable',
#   'extended',
#   'light',
#   'periods',
#   'plenty',
#   'somewhat',
#   'time',
#   'wear'],
#  ['disappointing'],
#  ['ant', 'blue', 'easy', 'use'],
#  ['cheap',
#   'cost',
#   'given',
#   'hey',
#   'item',
#   'low',
#   'pleasantly',
#   'suprised',
#   'works'],
#  ['camera',
#   'disposable',
#   'dustpan',
#   'indoors',
#   'may',
#   'phone',
#   'rather',
#   'used',
#   'using',
#   'would'],
#  ['came', 'days', 'later', 'phone', 'puff', 'smoke', 'use'],
#  ['car',
#   'convenient',
#   'done',
#   'gets',
#   'job',
#   'makes',
#   'much',
#   'ride',
#   'simple',
#   'smoother',
#   'use'],
#  ['dissapointed', 'nano', 'son', 'stated'],
#  ['excellent', 'quality', 'sound', 'well'],
#  ['best', 'headset', 'used'],
#  ['not', 'reccommend', 'would'],
#  ['anti',
#   'around',
#   'carries',
#   'date',
#   'found',
#   'glare',
#   'highest',
#   'protector',
#   'quality',
#   'screen',
#   'years'],
#  ['wanted'],
#  ['model', 'motorola', 'not', 'particular', 'smartphone', 'work', 'would'],
#  ['atleast', 'right', 'wont', 'work'],
#  ['addition',
#   'amp',
#   'cheap',
#   'feels',
#   'lightweight',
#   'looks',
#   'phone',
#   'plastic'],
#  ['bottom',
#   'cingular',
#   'else',
#   'line',
#   'money',
#   'not',
#   'problems',
#   'put',
#   'reoccure',
#   'somewhere',
#   'support',
#   'warranty'],
#  ['good', 'issues', 'many', 'one', 'plantronics', 'really', 'right', 'wanted'],
#  ['great', 'product'],
#  ['clear', 'crisp'],
#  ['charge', 'dead', 'first', 'going', 'kept', 'minutes'],
#  ['cheap', 'creaks', 'floor', 'like', 'old', 'plastic', 'wooden'],
#  ['absolutely',
#   'apartment',
#   'get',
#   'horrible',
#   'not',
#   'phones',
#   'problem',
#   'reception'],
#  ['generally', 'good', 'reception'],
#  ['battery', 'boot', 'excellent', 'inconspicuous', 'life', 'sound'],
#  ['bluetooth', 'great'],
#  ['case', 'highly', 'recommend'],
#  ['worthwhile'],
#  ['deal', 'great'],
#  ['breaking',
#   'care',
#   'despite',
#   'got',
#   'much',
#   'old',
#   'part',
#   'phone',
#   'slowly',
#   'year'],
#  ['made', 'purchase', 'sorry'],
#  ['better',
#   'bluetooth',
#   'bought',
#   'could',
#   'fit',
#   'headset',
#   'hoping',
#   'impossible',
#   'made',
#   'make',
#   'things',
#   'wear'],
#  ['another',
#   'buy',
#   'discount',
#   'forced',
#   'kind',
#   'mobile',
#   'phone',
#   'refused',
#   'replace',
#   'treo',
#   'upgrade',
#   'without'],
#  ['horrible'],
#  ['belt', 'hold', 'not', 'securly', 'think', 'would'],
#  ['allows', 'booking', 'date', 'double', 'first', 'possibility', 'time'],
#  ['break', 'weeks', 'work'],
#  ['like', 'simple', 'use'],
#  ['activesync',
#   'communication',
#   'data',
#   'entertainment',
#   'great',
#   'management',
#   'oh',
#   'optimal',
#   'results',
#   'sure',
#   'synchronization',
#   'tool',
#   'use'],
#  ['cannot', 'case', 'disgusting', 'smell', 'use'],
#  ['not', 'wanted'],
#  ['another', 'cases', 'order', 'would'],
#  ['great', 'phone'],
#  ['amazon', 'battery', 'bought', 'coupon', 'happy', 'purchase'],
#  ['access', 'fine', 'instance', 'internet', 'rare', 'worked'],
#  ['perfect', 'ps'],
#  ['five', 'plus', 'star'],
#  ['awful',
#   'bargain',
#   'big',
#   'bought',
#   'cheapy',
#   'could',
#   'end',
#   'good',
#   'hear',
#   'lots',
#   'not',
#   'people',
#   'quality',
#   'sounded'],
#  ['drain'],
#  ['gets',
#   'great',
#   'loud',
#   'not',
#   'old',
#   'real',
#   'shouting',
#   'still',
#   'talking',
#   'telephone',
#   'told',
#   'tried'],
#  ['fine', 'good', 'works'],
#  ['deal', 'great', 'price'],
#  ['great', 'price'],
#  ['completely', 'useless', 'wind'],
#  ['front', 'love', 'shiny', 'side', 'yes'],
#  ['not', 'work'],
#  ['deal',
#   'first',
#   'good',
#   'grtting',
#   'phone',
#   'plugged',
#   'razr',
#   'thought',
#   'vc'],
#  ['excellent', 'headset', 'reception'],
#  ['seller', 'thumbs'],
#  ['exceeds',
#   'feet',
#   'good',
#   'lg',
#   'line',
#   'phone',
#   'range',
#   'reception',
#   'sight',
#   'together',
#   'verizon',
#   'well',
#   'work'],
#  ['description', 'improper', 'return'],
#  ['comfortable', 'works'],
#  ['battery', 'charge', 'life', 'long', 'quite'],
#  ['eargels', 'ears', 'fit', 'jabra', 'well'],
#  ['battery', 'life', 'no'],
#  ['checked', 'disappointing', 'everywhere', 'feature', 'no', 'really'],
#  ['described', 'exactly', 'product'],
#  ['gets', 'phones', 'signal', 'verizon', 'wont'],
#  ['doesnt', 'job'],
#  ['recommend', 'would'],
#  ['ordering', 'plan'],
#  ['camera',
#   'cool',
#   'decent',
#   'effects',
#   'many',
#   'nice',
#   'phone',
#   'play',
#   'said',
#   'video',
#   'well'],
#  ['cell', 'day', 'one', 'phone', 'satisfied'],
#  ['better', 'getting', 'keep', 'numerous', 'one', 'palms', 'third'],
#  ['awkward', 'unreliable', 'use'],
#  ['also', 'quick', 'shipping', 'time'],
#  ['good', 'hoped', 'not'],
#  ['case', 'good'],
#  ['doesnt', 'work'],
#  ['good', 'product', 'really'],
#  ['not', 'unfortunately', 'work'],
#  ['broke', 'months', 'three', 'two', 'use', 'within'],
#  ['buy', 'dont'],
#  ['battery', 'dying', 'father'],
#  ['come', 'ear', 'easily', 'however', 'lost', 'one', 'pads', 'week'],
#  ['black',
#   'calls',
#   'comes',
#   'drop',
#   'goes',
#   'intermittently',
#   'phone',
#   'ringing',
#   'screen',
#   'stops',
#   'worst'],
#  ['horrible', 'protector'],
#  ['either', 'like', 'nokia', 'not'],
#  ['bottom',
#   'end',
#   'expect',
#   'keys',
#   'not',
#   'reaching',
#   'row',
#   'send',
#   'uncomfortable'],
#  ['ago', 'bought', 'cell', 'nightmare', 'nokia', 'phone', 'weeks'],
#  ['amazon',
#   'bad',
#   'customer',
#   'describe',
#   'experience',
#   'long',
#   'service',
#   'take',
#   'would'],
#  ['disappointing', 'no', 'speakerphone', 'thing'],
#  ['accept', 'car', 'cassette', 'not', 'terrible'],
#  ['cellphones',
#   'charge',
#   'charging',
#   'current',
#   'enough',
#   'not',
#   'planning',
#   'product',
#   'since',
#   'use',
#   'useless'],
#  ['not', 'says'],
#  ['away', 'stay'],
#  ['dirty', 'used'],
#  ['mobile', 'service', 'unreliable'],
#  ['enough', 'good', 'not', 'price'],
#  ['bought', 'charge', 'neither', 'two'],
#  ['looks', 'nice'],
#  ['answer', 'auto', 'especially', 'excellent', 'paired', 'phones', 'tool'],
#  ['not', 'others', 'problem', 'read', 'reviews'],
#  ['cover', 'ear', 'important', 'light', 'outlet', 'products', 'sensor'],
#  ['comfortable', 'hand'],
#  ['not', 'work'],
#  ['poor', 'reliability'],
#  ['works'],
#  ['bar',
#   'battery',
#   'beeping',
#   'dieing',
#   'drops',
#   'know',
#   'letting',
#   'picture',
#   'starts',
#   'take'],
#  ['money', 'product', 'terrible', 'waste'],
#  ['buying', 'last', 'time'],
#  ['money', 'waste'],
#  ['charm', 'far', 'like', 'worked'],
#  ['far', 'good', 'weeks'],
#  ['best',
#   'case',
#   'download',
#   'even',
#   'ir',
#   'laptop',
#   'part',
#   'phone',
#   'pictures',
#   'send',
#   'using'],
#  ['item', 'recommend', 'would'],
#  ['cancellation',
#   'choice',
#   'good',
#   'great',
#   'headset',
#   'noise',
#   'sound',
#   'volume',
#   'years'],
#  ['case', 'feels', 'good', 'hands', 'nice'],
#  ['counterfeit', 'item', 'received'],
#  ['best', 'bt', 'ever', 'far', 'good', 'headset', 'probably', 'really'],
#  ['fine', 'works'],
#  ['good', 'happy', 'headset', 'received', 'time'],
#  ['blackberry',
#   'could',
#   'flip',
#   'holster',
#   'pleased',
#   'replace',
#   'see',
#   'swivel',
#   'travled',
#   'well'],
#  ['also', 'loves', 'one', 'sister'],
#  ['good', 'quality'],
#  ['amazon', 'far', 'made', 'purchase', 'worst'],
#  ['dual', 'excellent', 'headset', 'purpose'],
#  ['excellent'],
#  ['cingular', 'listening', 'music', 'not', 'work'],
#  ['belt',
#   'completely',
#   'holding',
#   'inside',
#   'iphone',
#   'keeping',
#   'secure',
#   'seems'],
#  ['another', 'bottowm', 'cheap', 'gimmick', 'line', 'sprint', 'worthless'],
#  ['trouble', 'volume'],
#  ['comfortably', 'ears', 'fits', 'good', 'small', 'thing'],
#  ['buy', 'not', 'warning'],
#  ['could', 'far', 'happier', 'iphone', 'not', 'pairing'],
#  ['battery', 'broken', 'connection', 'device', 'opens', 'turned'],
#  ['causing', 'clip', 'discomfort', 'ear', 'going', 'not', 'top', 'want'],
#  ['best', 'ever', 'headset'],
#  ['dont', 'expect', 'helpful', 'not', 'support', 'trust', 'website'],
#  ['cell',
#   'connection',
#   'flawless',
#   'glad',
#   'loud',
#   'maintains',
#   'no',
#   'normal',
#   'plantronics',
#   'say',
#   'static',
#   'use'],
#  ['cheap', 'low', 'making', 'quality', 'ring', 'sound', 'speaker', 'tones'],
#  ['came', 'comfortably', 'earbud', 'fits', 'sizes', 'three', 'tips'],
#  ['excellent', 'price', 'product'],
#  ['bad', 'reception'],
#  ['chinese', 'crap', 'high', 'product', 'quality'],
#  ['comfortable', 'ear', 'quite'],
#  ['great', 'phone'],
#  ['buy', 'dont', 'fails', 'product'],
#  ['everything', 'first', 'product', 'wrong'],
#  ['barely',
#   'calls',
#   'couple',
#   'devices',
#   'dialing',
#   'easy',
#   'feature',
#   'making',
#   'minutes',
#   'pairing',
#   'started',
#   'took',
#   'two',
#   'voice'],
#  ['caused',
#   'confusing',
#   'contacts',
#   'couple',
#   'first',
#   'important',
#   'lose',
#   'utterly'],
#  ['holder', 'phone', 'terrible'],
#  ['buttons', 'cutouts', 'perfectly', 'placed'],
#  ['able', 'cell', 'headset', 'land', 'line', 'love', 'one', 'use'],
#  ['break', 'ear', 'easily', 'loops', 'made', 'material', 'problem', 'weak'],
#  ['amazon', 'good', 'look', 'looking', 'makes', 'nearly', 'not', 'picture'],
#  ['additional',
#   'case',
#   'costs',
#   'despite',
#   'exceptional',
#   'flaws',
#   'oem',
#   'official',
#   'owning',
#   'product',
#   'quality',
#   'well',
#   'worth'],
#  ['stupid'],
#  ['car',
#   'driving',
#   'even',
#   'hear',
#   'loudest',
#   'not',
#   'put',
#   'setting',
#   'usually'],
#  ['cheaper', 'competitors', 'much', 'quickly', 'seller', 'shipped'],
#  ['good', 'samsung', 'show'],
#  ['alot', 'bought', 'money', 'saved'],
#  ['always', 'beep', 'cuts', 'failed', 'makes', 'says', 'signal', 'sound'],
#  ['couldnt', 'figure'],
#  ['almost',
#   'could',
#   'great',
#   'not',
#   'ok',
#   'phone',
#   'said',
#   'sounded',
#   'totally',
#   'understand',
#   'unintelligible',
#   'wifes',
#   'word'],
#  ['back', 'battery', 'phone', 'put', 'restart', 'take', 'together'],
#  ['back',
#   'bend',
#   'break',
#   'drop',
#   'enough',
#   'leaf',
#   'managed',
#   'metal',
#   'next',
#   'place',
#   'spring',
#   'stress'],
#  ['leopard', 'print', 'wild', 'wonderfully'],
#  ['works'],
#  ['floppy', 'junk', 'piece', 'saggy'],
#  ['better', 'cases', 'hard', 'much', 'plastic'],
#  ['also', 'new', 'problem'],
#  ['far', 'happy'],
#  ['cool', 'phone'],
#  ['good', 'works'],
#  ['bluetooth',
#   'finally',
#   'got',
#   'headset',
#   'motorola',
#   'quality',
#   'right',
#   'voice'],
#  ['connection', 'couple', 'even', 'feet', 'looses', 'phone', 'two', 'within'],
#  ['great', 'really', 'recommend', 'would'],
#  ['bluetooth', 'easier', 'keep', 'makes', 'not', 'wearing'],
#  ['pretty', 'said', 'useless'],
#  ['got', 'never'],
#  ['ever', 'headphones', 'pair', 'sound', 'wise', 'worst'],
#  ['[]', 'drain', 'snap', 'weak'],
#  ['att', 'charge', 'cingular', 'not', 'phone'],
#  ['call', 'carry', 'cut', 'extra', 'get', 'minutes', 'not'],
#  ['black',
#   'calls',
#   'could',
#   'eventually',
#   'fliptop',
#   'get',
#   'however',
#   'loose',
#   'not',
#   'place',
#   'receive',
#   'screen',
#   'started',
#   'went',
#   'wobbly',
#   'year'],
#  ['cable', 'catching', 'kept', 'phone', 'pull', 'seat', 'turn'],
#  ['fulfills', 'happy', 'headset', 'purchase', 'requirements'],
#  ['bluetooth', 'headset', 'logitech'],
#  ['ear', 'fact', 'inside', 'lightly', 'like', 'rather', 'rests'],
#  ['good', 'lot', 'phone', 'rating', 'websites'],
#  ['cables', 'computer', 'fine', 'ipod', 'tried', 'works'],
#  ['joke', 'low', 'mic', 'quite', 'volume'],
#  ['returning'],
#  ['computer', 'connection', 'lap', 'maintain', 'not'],
#  ['accessable', 'car', 'controls', 'easy', 'quite', 'turn', 'volume'],
#  ['bought', 'christmas', 'family', 'mine', 'rest', 'year'],
#  ['clear', 'easy', 'install', 'otherwise', 'sound', 'use'],
#  ['leather', 'nice'],
#  ['case', 'different', 'purchase'],
#  ['joy', 'use'],
#  ['company', 'disappointed', 'much'],
#  ['satisifed'],
#  ['charge', 'not'],
#  ['bought', 'get', 'phone', 'sa', 'say', 'wow'],
#  ['buttons', 'small'],
#  ['alone', 'makes', 'reading', 'say', 'specs', 'wow'],
#  ['armband', 'great', 'love'],
#  ['allot',
#   'clearer',
#   'ear',
#   'like',
#   'mic',
#   'motorola',
#   'piece',
#   'product',
#   'really'],
#  ['buttons', 'however', 'keypads', 'reach', 'sometimes', 'tinny', 'wrong'],
#  ['decision', 'ericson', 'exchanged', 'happy', 'pretty', 'sony', 'za'],
#  ['cases', 'impressed', 'price'],
#  ['also', 'easier', 'hold', 'makes'],
#  ['center',
#   'control',
#   'equipment',
#   'great',
#   'high',
#   'humming',
#   'lot',
#   'motor',
#   'product',
#   'use',
#   'voltage',
#   'works'],
#  ['easy', 'pretty'],
#  ['calls', 'cannot', 'certain', 'make', 'places'],
#  ['complain',
#   'girl',
#   'however',
#   'like',
#   'normal',
#   'not',
#   'phone',
#   'time',
#   'wake'],
#  ['beautiful', 'styling', 'though'],
#  ['back',
#   'charge',
#   'company',
#   'fee',
#   'given',
#   'not',
#   'refund',
#   'restocking',
#   'still'],
#  ['refund', 'return', 'trying'],
#  ['darn', 'find', 'not', 'plugged', 'thing', 'worked'],
#  ['excellent', 'product'],
#  ['breaks', 'earbud', 'easily', 'piece'],
#  ['lousy', 'product'],
#  ['ability', 'everything', 'fails', 'hard', 'phone', 'tries'],
#  ['best', 'charger', 'market', 'seen', 'yet'],
#  ['phone', 'sweetest'],
#  ['charger', 'fine', 'oh', 'seems', 'work'],
#  ['better',
#   'canal',
#   'directed',
#   'ear',
#   'even',
#   'fits',
#   'hook',
#   'need',
#   'not',
#   'securely',
#   'sound',
#   'used'],
#  ['enough', 'not', 'volume'],
#  ['echo', 'problem', 'unsatisfactory'],
#  ['could', 'poor', 'quality', 'take', 'time', 'videos'],
#  ['money', 'not', 'waste'],
#  ['first', 'going', 'negatively', 'product', 'review'],
#  ['adapter', 'charging', 'current', 'enough', 'not', 'provide'],
#  ['assumed', 'best', 'hype', 'mistake', 'much', 'phone'],
#  ['also', 'cannot', 'case', 'covered', 'lense', 'pictures', 'take'],
#  ['easily', 'falls', 'phone'],
#  ['hear', 'not', 'people', 'talk', 'work'],
#  ['feature', 'messaging', 'really', 'text', 'tricky', 'use'],
#  ['charger', 'disappointed', 'not', 'really', 'work'],
#  ['ear', 'painful'],
#  ['blew', 'day', 'lasted', 'one'],
#  ['disappointed'],
#  ['around', 'flops', 'kind'],
#  ['ear', 'easily', 'face', 'get', 'screen', 'smudged', 'touches'],
#  ['calls', 'junk', 'lose', 'phone', 'piece'],
#  ['item', 'match', 'not', 'picture'],
#  ['disappoint', 'infra', 'irda', 'port', 'red', 'thing'],
#  ['answer', 'calls', 'never', 'not', 'unit', 'worked'],
#  ...]

# %% [markdown]
# Veamos los primeros comentarios.
#
# En particular observa si "minutes" y "major" están como dos tokens separados en el cuarto comentario. De nos ser así, si aparecen juntos como un solo token, debes revisar tu proceso de limpieza anterior, porque esto significa que pueden existir otros muchos casos que nos llevan a esta salida no deseada. Trata de determinar el origen de este problema (y solo en caso de que te haya aparecido como un solo token "minutesmajor", en el cuarto comentario).

# %%
for x in Xcleantok[0:5]:
  print(x)
# Out:
# ['converter', 'go', 'no', 'plug', 'unless', 'us', 'way']
# ['case', 'excellent', 'good', 'value']
# ['great', 'jawbone']
# ['charger', 'conversations', 'lasting', 'major', 'minutes', 'problems', 'tied']
# ['great', 'mic']

# %% [markdown]
# ##**Pregunta - 5:**

# %% [markdown]
# Esta pregunta es abierta y podrás incluir todos aquellos procesos de limpieza adicionales que desees.
#
# Por ejemplo, puedes decidir aplicar algunos procesos (regex) para simplificar caracteres que aparecen repetidos más de dos veces, o bien simplificar algunas conjugaciones de verbos regulares para no incluir terminaciones en "s", "ed" o "ing". Puedes también decidir aplicar alguna de las técnicas de stemming o de lemmatization, etc.
#
# NOTA: Deberás aplicar al menos dos procesos de limpieza o normalización adicionales en esta función que llamamos simplemente clean_doc().
#
# La entrada son cada una de las listas con los comentarios tokenizados de Xcleantok y la salida es una lista de tokens simplficados/normalizados con el nombre de "tokens". En dado caso, algunos de los comentarios tokenizados pudieran no surgir cambio alguno bajo esta función.
#
# Recuerda que el objetivo de esta función "clean_doc()" es tener datos más limpios para el proceso de entrenamiento con los algoritmos de aprendizaje automático que se realizarán en las últimas preguntas.
#
# Puedes inspeccionar de manera aleatoria algunos de los 3000 registros para determinar qué procesos de limpieza adicionales incluir.

# %%
##############################################################################
# AGREGA AQUÍ TUS LÍNEAS DE CÓDIGO - Pregunta 5:

# Aquí puedes incluir las librerías, paquetes o líneas de código necesarias para
# el proceso de limpieza adicional de esta pregunta:

from nltk.stem import WordNetLemmatizer, PorterStemmer
nltk.download('wordnet')
nltk.download('omw-1.4')

def clean_doc(doc):

  stemmer = PorterStemmer()
# wnl = WordNetLemmatizer()
  tokens = []
  
  for token in doc:
    tokens.append (stemmer.stem(token))


  return tokens
  # FIN PARA AGREGAR TUS LÍNEAS DE CÓDIGO.
  ##############################################################################
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/rafaeljosem/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /home/rafaeljosem/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
# Aplicamos el proceso de limpieza/normalización adicionales:

Xclean = [clean_doc(x) for x in Xcleantok]

# %%
Xclean         # Veamos los primero registros para ver cómo va quedando el resultado.
# Out:
# [['convert', 'go', 'no', 'plug', 'unless', 'us', 'way'],
#  ['case', 'excel', 'good', 'valu'],
#  ['great', 'jawbon'],
#  ['charger', 'convers', 'last', 'major', 'minut', 'problem', 'tie'],
#  ['great', 'mic'],
#  ['decent', 'get', 'jiggl', 'line', 'plug', 'right', 'volum'],
#  ['contact', 'dozen', 'fun', 'hundr', 'imagin', 'one', 'send', 'sever'],
#  ['must', 'owner', 'razr'],
#  ['money', 'needless', 'say', 'wast'],
#  ['money', 'time', 'wast'],
#  ['great', 'qualiti', 'sound'],
#  ['batteri', 'extend', 'go', 'impress', 'origin'],
#  ['excess',
#   'ft',
#   'garbl',
#   'headset',
#   'mere',
#   'notic',
#   'seper',
#   'sound',
#   'start',
#   'static',
#   'two'],
#  ['good', 'qualiti', 'though'],
#  ['clip', 'comfort', 'design', 'ear', 'not', 'odd'],
#  ['blue', 'highli', 'one', 'phone', 'recommend', 'tooth'],
#  ['advis', 'everyon', 'fool', 'not'],
#  ['far', 'good'],
#  ['great', 'work'],
#  ['click',
#   'last',
#   'long',
#   'make',
#   'mechan',
#   'place',
#   'way',
#   'wonder',
#   'would'],
#  ['could',
#   'direct',
#   'follow',
#   'get',
#   'motorola',
#   'not',
#   'pair',
#   'websit',
#   'went'],
#  ['absolut', 'bought', 'fire', 'kindl', 'love', 'use'],
#  ['commerci', 'mislead'],
#  ['bar',
#   'batteri',
#   'charg',
#   'day',
#   'new',
#   'run',
#   'three',
#   'two',
#   'without',
#   'yet'],
#  ['batteri', 'bought', 'mother', 'problem'],
#  ['combin', 'great', 'pc', 'phone', 'pocket'],
#  ['best', 'mobil', 'month', 'own', 'phone', 'say'],
#  ['help', 'instruct', 'not', 'provid', 'think'],
#  ['couldnt', 'earphon', 'hear', 'peopl', 'phone', 'pull', 'talk'],
#  ['charg', 'doesnt', 'hold'],
#  ['breakag', 'littl', 'phone', 'simpl', 'unaccept', 'use'],
#  ['ear', 'ideal', 'like', 'peopl', 'product', 'sensit', 'whose'],
#  ['car', 'freeway', 'move', 'speed', 'unus'],
#  ['contract', 'hate', 'left', 'phone', 'two', 'year'],
#  ['ac',
#   'car',
#   'charger',
#   'highi',
#   'includ',
#   'juic',
#   'make',
#   'never',
#   'recommend',
#   'run',
#   'sure',
#   'well'],
#  ['batteri',
#   'book',
#   'first',
#   'get',
#   'least',
#   'life',
#   'min',
#   'need',
#   'phone',
#   'short',
#   'time',
#   'turn'],
#  ['kept', 'well'],
#  ['perform', 'poor', 'talk', 'time'],
#  ['case', 'fine', 'great', 'work'],
#  ['product', 'worthless'],
#  ['camera',
#   'clear',
#   'great',
#   'mp',
#   'nice',
#   'pic',
#   'pictur',
#   'qualiti',
#   'that'],
#  ['impress', 'not', 'product'],
#  ['headset', 'nice', 'price', 'right'],
#  ['audio', 'garbag', 'hear'],
#  ['bluetooth', 'excel', 'headset'],
#  ['featur', 'want'],
#  ['batteri', 'buy', 'gonna', 'mind', 'right'],
#  ['argu',
#   'call',
#   'day',
#   'drop',
#   'phone',
#   'regard',
#   'return',
#   'two',
#   'verizon'],
#  ['case', 'made', 'seem', 'well'],
#  ['batteri', 'disappoint'],
#  ['enough', 'like', 'loud', 'not', 'turn'],
#  ['bulki', 'good', 'make', 'not', 'phone', 'protect'],
#  ['actual',
#   'gadget',
#   'instead',
#   'keyboard',
#   'machin',
#   'neat',
#   'pda',
#   'real',
#   'turn',
#   'usabl',
#   'use',
#   'world'],
#  ['larg', 'never', 'phone', 'pretti', 'problem', 'sturdi'],
#  ['love', 'thing'],
#  ['everyth', 'fine', 'price', 'reason'],
#  ['disappoint'],
#  ['drop',
#   'even',
#   'great',
#   'phone',
#   'second',
#   'still',
#   'stream',
#   'submerg',
#   'work'],
#  ['complaint', 'end', 'happi', 'no', 'one', 'qualiti', 'regard', 'sound'],
#  ['bad', 'button'],
#  ['essenti', 'forget', 'microsoft', 'support', 'tech'],
#  ['cool', 'eleg', 'facepl', 'look', 'nice', 'realli', 'recommend', 'sinc'],
#  ['best',
#   'find',
#   'great',
#   'headphon',
#   'last',
#   'made',
#   'perhap',
#   'purchas',
#   'serious',
#   'sever',
#   'think',
#   'year'],
#  ['buy', 'differ', 'not', 'phone'],
#  ['angl', 'clearli', 'hear', 'hold', 'particular', 'parti', 'phone'],
#  ['big',
#   'button',
#   'cover',
#   'drawback',
#   'front',
#   'let',
#   'lock',
#   'mp',
#   'one',
#   'paus',
#   'phone',
#   'player',
#   'second',
#   'skip',
#   'song'],
#  ['activ', 'die', 'later', 'suddenli', 'week'],
#  ['comfort', 'feel', 'get', 'glass', 'headset', 'sometim', 'way', 'wear'],
#  ['great', 'ipod'],
#  ['devic', 'great', 'sever', 'situat'],
#  ['doesnt', 'mic', 'work'],
#  ['bmw', 'even', 'fairli', 'hear', 'person', 'quiet', 'say', 'seri', 'troubl'],
#  ['choic', 'great'],
#  ['dock', 'home', 'nice', 'station', 'work'],
#  ['beauti', 'phone'],
#  ['love', 'product'],
#  ['advertis', 'buy', 'not', 'wrongli'],
#  ['great', 'item', 'littl'],
#  ['featur', 'handi', 'lot', 'love', 'phone'],
#  ['day', 'longer', 'no', 'purchas', 'within', 'work'],
#  ['everyday', 'hold', 'wear', 'well'],
#  ['bargain', 'good', 'not'],
#  ['arriv', 'intend', 'packag', 'time', 'well', 'work'],
#  ['batteri', 'quickli', 'run'],
#  ['broke', 'great', 'item', 'month', 'use', 'work'],
#  ['easi', 'everyon', 'headset', 'love', 'use'],
#  ['great', 'phone', 'work'],
#  ['construct', 'headset', 'poor'],
#  ['better', 'boy', 'cheaper', 'excel', 'one', 'product', 'verizon', 'work'],
#  ['load', 'phone', 'super'],
#  ['better',
#   'cost',
#   'eas',
#   'expect',
#   'far',
#   'greater',
#   'much',
#   'one',
#   'product',
#   'thing',
#   'work'],
#  ['made', 'sturdi'],
#  ['great', 'work'],
#  ['bud', 'ear', 'music', 'one', 'play'],
#  ['dont', 'money', 'wast'],
#  ['order'],
#  ['car', 'forget', 'plan', 'use'],
#  ['big', 'found', 'product', 'waaay'],
#  ['best',
#   'bluetooth',
#   'eas',
#   'far',
#   'found',
#   'listen',
#   'one',
#   'qualiti',
#   'tri',
#   'use',
#   'well'],
#  ['decis', 'disappoint'],
#  ['integr', 'motorola', 'phone', 'razr', 'seamlessli'],
#  ['bewar', 'buyer', 'could', 'flush', 'money', 'right', 'toilet'],
#  ['bargain', 'definit'],
#  ['free', 'good', 'price', 'purchas', 'ship'],
#  ['appar',
#   'charger',
#   'match',
#   'motorola',
#   'new',
#   'not',
#   'phone',
#   'receiv',
#   'supposedli'],
#  ['also',
#   'black',
#   'camera',
#   'cool',
#   'good',
#   'like',
#   'nice',
#   'pictur',
#   'pro',
#   'style',
#   'white'],
#  ['case',
#   'correctli',
#   'design',
#   'flaw',
#   'huge',
#   'not',
#   'that',
#   'think',
#   'unless',
#   'use'],
#  ['bluetooth',
#   'comfort',
#   'ear',
#   'fit',
#   'good',
#   'great',
#   'headset',
#   'jabra',
#   'love',
#   'piec',
#   'recept'],
#  ['although',
#   'camera',
#   'expect',
#   'fall',
#   'high',
#   'imag',
#   'impress',
#   'megapixel',
#   'rate',
#   'rel',
#   'render',
#   'resolut',
#   'well'],
#  ['car', 'charger', 'not', 'purcash', 'work'],
#  ['ask', 'call', 'end', 'excel', 'headset', 'qualiti', 'sound', 'use', 'wife'],
#  ['beauti', 'display', 'light', 'phone', 'slim'],
#  ['batteri',
#   'case',
#   'embed',
#   'geeki',
#   'leather',
#   'littl',
#   'ooz',
#   'right',
#   'rock',
#   'sex',
#   'sleek',
#   'stylish',
#   'that',
#   'think',
#   'toast'],
#  ['fast', 'great', 'product', 'ship'],
#  ['absolut', 'great'],
#  ['basic',
#   'cell',
#   'compromis',
#   'full',
#   'keyboard',
#   'keypad',
#   'nice',
#   'number',
#   'phone',
#   'qwerti'],
#  ['around', 'complet', 'end', 'got', 'may', 'phone', 'unhappi'],
#  ['comfort', 'ear'],
#  ['us', 'winner'],
#  ['could', 'not', 'setup', 'simpler'],
#  ['cell',
#   'comfort',
#   'differ',
#   'ear',
#   'earpiec',
#   'first',
#   'fit',
#   'found',
#   'jabra',
#   'one',
#   'phone',
#   'sever',
#   'tri'],
#  ['could', 'enough', 'get', 'not', 'signal', 'strong'],
#  ['iam', 'pleas', 'purchas'],
#  ['bad', 'qualiti'],
#  ['done', 'get', 'job'],
#  ['audio', 'great'],
#  ['bad', 'basic', 'servic'],
#  ['cell', 'charger', 'not', 'phone', 'plug', 'set', 'work'],
#  ['bluetooth', 'like', 'realli', 'week'],
#  ['bt', 'disapoin', 'headset'],
#  ['even', 'get', 'not', 'realiz', 'small', 'use'],
#  ['accompani', 'almost', 'brilliant', 'softwar'],
#  ['avoid', 'damag', 'great', 'headset', 'nice', 'packag', 'work'],
#  ['definitli', 'recommend'],
#  ['buyer', 'care'],
#  ['earbud', 'fail', 'headset', 'logitech', 'major'],
#  ['good', 'price', 'stuff'],
#  ['headset', 'keen', 'peachi', 'work'],
#  ['basement', 'coverag', 'drop', 'get', 'hous', 'no', 'upstair'],
#  ['recognit', 'tremend', 'voic'],
#  ['wast'],
#  ['area', 'bar', 'call', 'differ', 'drop', 'experienc', 'minut', 'sever'],
#  ['happi', 'item', 'not'],
#  ['disappoint'],
#  ['charg', 'forev', 'hour', 'like', 'liter', 'phone', 'take'],
#  ['glad', 'got', 'phone', 'reccomend', 'rel'],
#  ['time', 'wast'],
#  ['poor', 'recept'],
#  ['descript', 'includ', 'item', 'not', 'state'],
#  ['black', 'month', 'screen', 'sudden', 'went'],
#  ['hope'],
#  ['audio', 'poor', 'qualiti'],
#  ['absolut', 'blackberri', 'curv', 'headset', 'link', 'no', 'problem'],
#  ['funni',
#   'great',
#   'know',
#   'like',
#   'not',
#   'one',
#   'seem',
#   'sketchi',
#   'sound',
#   'technolog',
#   'well',
#   'work',
#   'work',
#   'would'],
#  ['better', 'bought', 'headphon', 'sound', 'wire'],
#  ['brows',
#   'fast',
#   'faster',
#   'kind',
#   'messag',
#   'phone',
#   'phone',
#   'previou',
#   'send',
#   'significantli',
#   'use',
#   'web'],
#  ['build', 'cheap', 'nice', 'qualiti', 'unlik'],
#  ['fantast', 'item', 'perfectli', 'work'],
#  ['color', 'love'],
#  ['superb', 'wi'],
#  ['goe', 'internet', 'less', 'like', 'thing', 'use', 'whine'],
#  ['charger', 'great'],
#  ['commun', 'commun', 'essenti', 'not', 'tool'],
#  ['charm', 'got', 'like', 'one', 'phone', 'work', 'work'],
#  ['copi',
#   'design',
#   'dna',
#   'enough',
#   'headphon',
#   'human',
#   'maintain',
#   'make',
#   'monkey',
#   'not',
#   'obvious',
#   'share',
#   'still'],
#  ['great', 'valu'],
#  ['bougth', 'doesnt', 'lc', 'not', 'work', 'work'],
#  ['clear', 'graphic', 'great', 'look', 'nice', 'screen', 'sharp'],
#  ['last', 'long', 'not'],
#  ['button', 'hate', 'mode', 'one', 'set', 'side', 'thing'],
#  ['excel', 'servic'],
#  ['money', 'thank', 'wast'],
#  ['audio', 'beth', 'poor', 'qualiti'],
#  ['charger', 'great', 'igo', 'realli', 'tip'],
#  ['browser', 'file', 'great', 'handsfre', 'need', 'offer', 'one', 'option'],
#  ['great', 'network', 'phone', 'superb'],
#  ['bluetoothmotorola',
#   'case',
#   'charm',
#   'connect',
#   'hs',
#   'like',
#   'phone',
#   'pocket',
#   'whether',
#   'wife',
#   'work'],
#  ['crawl', 'everi', 'latest', 'like', 'lock', 'os', 'put', 'slow'],
#  ['devic', 'phone', 'recogn', 'storag'],
#  ['buzz', 'convers', 'like', 'loud', 'overrid', 'phone'],
#  ['buy', 'dont', 'product'],
#  ['bluetoooth',
#   'comfort',
#   'ear',
#   'fit',
#   'headset',
#   'not',
#   'still',
#   'time',
#   'way'],
#  ['awesom', 'function', 'good', 'qualiti', 'sound'],
#  ['abhor', 'phone', 'realli', 'side', 'thorn'],
#  ['connect',
#   'could',
#   'disconnect',
#   'minut',
#   'not',
#   'problem',
#   'recent',
#   'stay'],
#  ['incred'],
#  ['design', 'flaw'],
#  ['great', 'phone'],
#  ['buck', 'wast'],
#  ['backlight',
#   'check',
#   'first',
#   'keypad',
#   'lost',
#   'mail',
#   'messag',
#   'night',
#   'second',
#   'turn',
#   'voic'],
#  ['die', 'replac', 'week'],
#  ['buy', 'good', 'overal', 'phone', 'ring', 'tone'],
#  ['extrem', 'help', 'late', 'nice', 'phone'],
#  ['drop', 'hit', 'problem', 'signal', 'wit'],
#  ['impress', 'not'],
#  ['hardli', 'light', 'notic', 'weight'],
#  ['love', 'thin', 'youll'],
#  ['bad', 'choic'],
#  ['case', 'fit', 'not', 'pleather'],
#  ['deaf', 'phone', 'simpli', 'useless'],
#  ['color',
#   'even',
#   'graphic',
#   'incred',
#   'prettier',
#   'sharp',
#   'thought',
#   'would'],
#  ['good', 'invest', 'think'],
#  ['call', 'end', 'make', 'nois', 'strang', 'tick'],
#  ['avail', 'best', 'electron', 'fm', 'transmitt'],
#  ['batteri', 'hour', 'last'],
#  ['great', 'headset', 'impress'],
#  ['camera', 'good', 'mega', 'part', 'phone', 'pixel', 'reason'],
#  ['great', 'nearli', 'work', 'year'],
#  ['audio', 'good', 'transmit'],
#  ['back', 'send'],
#  ['anyway',
#   'bother',
#   'bought',
#   'compani',
#   'contact',
#   'dollar',
#   'form',
#   'learn',
#   'lesson',
#   'not',
#   'onlin',
#   'product'],
#  ['avoid', 'earbug', 'hate', 'mean', 'phone'],
#  ['also', 'great', 'price'],
#  ['abl',
#   'around',
#   'decent',
#   'hous',
#   'issu',
#   'live',
#   'no',
#   'phone',
#   'qualiti',
#   'rang',
#   'recept',
#   'roam',
#   'room',
#   'sound'],
#  ['fast', 'servic'],
#  ['highli', 'recommend', 'would'],
#  ['recommend', 'would'],
#  ['also', 'button', 'crack', 'felt', 'like', 'not', 'use', 'would'],
#  ['ever', 'phone', 'worst'],
#  ['infatu', 'phone', 'still'],
#  ['freez', 'frequent'],
#  ['child', 'compani', 'embarrass', 'kind', 'like', 'look', 'mostli', 'use'],
#  ['fit', 'great', 'lightweight', 'simpl'],
#  ['better', 'consum', 'expect', 'experi', 'motorola', 'would'],
#  ['background',
#   'call',
#   'experienc',
#   'horribl',
#   'never',
#   'sound',
#   'there',
#   'tick'],
#  ['certainli', 'comfort', 'decent', 'function'],
#  ['hair', 'headband', 'lightweight', 'like', 'mess', 'not', 'one', 'usual'],
#  ['bit', 'disappoint'],
#  ['great', 'not', 'phone', 'tell', 'year'],
#  ['ericsson', 'first', 'order', 'soni', 'that', 'think', 'use', 'wi', 'work'],
#  ['batteri', 'complet', 'useless'],
#  ['big', 'time', 'wast'],
#  ['dont', 'one', 'wast'],
#  ['great', 'servic', 'sound'],
#  ['far', 'pleas', 'product', 'realli'],
#  ['ever', 'favorit', 'one', 'purchas'],
#  ['best', 'bluetooth', 'market'],
#  ['authent', 'case', 'comfort', 'leather', 'nice', 'recommend', 'shine'],
#  ['cute', 'excit', 'get', 'headset', 'realli', 'thought'],
#  ['make', 'mistak', 'not'],
#  ['big', 'calendar', 'disappoint', 'sync'],
#  ['new', 'not', 'phone', 'unus'],
#  ['custom', 'ever', 'servic', 'worst'],
#  ['addit', 'ear', 'gel', 'instruct', 'no', 'provid', 'whatsoev'],
#  ['bluetooth', 'defeat', 'headset', 'purpos'],
#  ['everi', 'penni', 'worth'],
#  ['case', 'excel', 'phone', 'type', 'wallet'],
#  ['great', 'headphon', 'nice', 'price', 'work'],
#  ['excrutiatingli', 'internet', 'slow'],
#  ['aspect', 'case', 'comfort', 'import', 'probabl', 'use', 'wear', 'well'],
#  ['durabl', 'fit', 'glove', 'like', 'secur', 'strong'],
#  ['best', 'ever', 'gosh', 'phone'],
#  ['appear', 'attract', 'good', 'qualiti'],
#  ['factor', 'featur', 'form', 'love'],
#  ['caus',
#   'petroleum',
#   'product',
#   'return',
#   'rubber',
#   'smell',
#   'strong',
#   'unbear'],
#  ['poor', 'qualiti', 'servic'],
#  ['cabl', 'flimsi', 'look', 'scari', 'thin'],
#  ['earpiec', 'great'],
#  ['excel', 'free', 'hand', 'tool'],
#  ['great', 'home', 'stereo', 'use'],
#  ['good', 'incred', 'product', 'valu'],
#  ['far', 'flawlessli', 'month', 'work'],
#  ['great', 'work'],
#  ['absolutel', 'junk'],
#  ['either', 'not', 'one', 'work'],
#  ['batteri', 'good', 'life', 'real'],
#  ['hour', 'later', 'return'],
#  ['great', 'item'],
#  ['dont', 'money', 'wast'],
#  ['headset', 'love'],
#  ['also', 'drain', 'fri', 'may', 'not', 'player', 'potenti'],
#  ['perfectli', 'work'],
#  ['give', 'unreli'],
#  ['gave', 'qualiti', 'sound', 'star'],
#  ['avoid', 'one'],
#  ['great', 'plug', 'revers', 'work'],
#  ['earpiec', 'littl', 'money', 'wast'],
#  ['good', 'phone'],
#  ['best', 'featur', 'help', 'rotat'],
#  ['comfort', 'famili', 'whole'],
#  ['good', 'product', 'seller'],
#  ['bluetooth', 'love'],
#  ['first', 'not', 'wear', 'well'],
#  ['headset', 'impress', 'plantron'],
#  ['ador', 'got', 'small'],
#  ['great', 'phone'],
#  ['buy', 'not', 'product', 'recommend', 'would'],
#  ['junk', 'piec'],
#  ['contstruct', 'hing', 'poorli'],
#  ['charg',
#   'everi',
#   'good',
#   'great',
#   'instal',
#   'item',
#   'let',
#   'no',
#   'overnit',
#   'problem',
#   'sinc',
#   'work'],
#  ['great', 'phone'],
#  ['buy', 'dont'],
#  ['excel', 'phone'],
#  ['not', 'phone', 'purchas'],
#  ['excel', 'handset', 'recognit', 'thru', 'voic'],
#  ['best', 'ever', 'hand', 'phone'],
#  ['attack',
#   'cat',
#   'destroy',
#   'great',
#   'instead',
#   'phone',
#   'protect',
#   'scratch',
#   'screen',
#   'strip',
#   'work'],
#  ['one', 'price', 'right', 'work'],
#  ['custom', 'servic', 'terribl'],
#  ['batteri',
#   'enough',
#   'life',
#   'long',
#   'motorola',
#   'not',
#   'razor',
#   'still',
#   'vi'],
#  ['back', 'send'],
#  ['decis', 'know', 'made', 'wise'],
#  ['invent', 'shouldv', 'someon', 'sooner'],
#  ['good', 'price'],
#  ['certainli',
#   'clever',
#   'construct',
#   'devic',
#   'engin',
#   'everyth',
#   'feel',
#   'first',
#   'good',
#   'tri',
#   'way',
#   'work'],
#  ['great', 'quickli', 'receiv', 'work'],
#  ['great', 'work'],
#  ['complain', 'found', 'headset', 'mani', 'microphon', 'peopl', 'weak'],
#  ['better', 'charg', 'hold', 'lot', 'nokia', 'old', 'tracfon', 'year'],
#  ['bit', 'care', 'consum', 'not', 'one'],
#  ['batteri', 'fast', 'good', 'got', 'realli'],
#  ['instruct', 'lack', 'manual'],
#  ['alarm',
#   'also',
#   'case',
#   'clock',
#   'dock',
#   'enough',
#   'fit',
#   'remov',
#   'slim',
#   'station',
#   'without'],
#  ['charg', 'hold', 'like', 'new', 'phone'],
#  ['antena', 'batteri', 'servic', 'unreli', 'use', 'well'],
#  ['compar',
#   'headset',
#   'lg',
#   'phone',
#   'plug',
#   'poor',
#   'previou',
#   'qualiti',
#   'quit',
#   'razr',
#   'sound',
#   'uncomfort',
#   'wire'],
#  ['compliment', 'gotten', 'lot'],
#  ['allow',
#   'cell',
#   'definit',
#   'drive',
#   'must',
#   'not',
#   'phone',
#   'state',
#   'usag'],
#  ['back', 'money', 'want'],
#  ['devic', 'love'],
#  ['also', 'happi', 'price'],
#  ['first', 'immedi', 'order', 'product', 'unhappi'],
#  ['earbud', 'lack', 'ngage', 'still'],
#  ['abl', 'car', 'dial', 'no', 'problem', 'voic'],
#  ['anyth', 'bar', 'cant', 'cell', 'hear', 'home', 'not', 'phone'],
#  ['good', 'item', 'low', 'price'],
#  ['best', 'game', 'howev', 'neither', 'not', 'riington'],
#  ['not', 'plug', 'well', 'work'],
#  ['amazon', 'suck'],
#  ['charg', 'rip', 'ship'],
#  ['comfort'],
#  ['ago',
#   'batteri',
#   'came',
#   'origin',
#   'phone',
#   'replac',
#   'well',
#   'work',
#   'year'],
#  ['excel', 'recept'],
#  ['charg',
#   'clear',
#   'comfort',
#   'coupl',
#   'day',
#   'ear',
#   'either',
#   'fit',
#   'last',
#   'loud',
#   'sound'],
#  ['button',
#   'clear',
#   'headset',
#   'ipod',
#   'mess',
#   'not',
#   'qualiti',
#   'sinc',
#   'sound'],
#  ['batteri', 'flip', 'frequentyli', 'last', 'long', 'not', 'phone', 'recharg'],
#  ['adhes', 'obvious', 'problem'],
#  ['disappoint'],
#  ['better', 'expect', 'inexpens', 'piec', 'qualiti', 'still', 'would'],
#  ['add', 'boost', 'bought', 'kind', 'not', 'practic', 'recept', 'useless'],
#  ['excel', 'qualiti', 'sound'],
#  ['happi', 'not'],
#  ['broke', 'day', 'junk', 'phone', 'piec'],
#  ['batteri', 'great', 'new', 'phone', 'work'],
#  ['custom', 'servic', 'worst'],
#  ['concret',
#   'drop',
#   'even',
#   'great',
#   'knock',
#   'phone',
#   'say',
#   'still',
#   'time',
#   'wood'],
#  ['full', 'recept', 'static', 'terribl'],
#  ['audio', 'good', 'qualiti'],
#  ['capabl',
#   'devic',
#   'easier',
#   'life',
#   'littl',
#   'lot',
#   'made',
#   'organiz',
#   'transform',
#   'whole'],
#  ['belt', 'cradl', 'headset', 'lost', 'signal', 'sit', 'vehicl'],
#  ['jerk', 'phone'],
#  ['advertis', 'charm', 'like', 'work'],
#  ['batteri', 'comfort', 'good', 'life', 'nice', 'rang'],
#  ['angel', 'coverag', 'horribl', 'lo', 'network'],
#  ['excel', 'headset', 'starter', 'wireless'],
#  ['appeal', 'bumper', 'great', 'light', 'loudspeak', 'option'],
#  ['could', 'headset', 'improv', 'leak', 'sound', 'thing', 'think'],
#  ['bar', 'ever', 'first', 'never', 'recept', 'suck'],
#  ['extrem', 'get', 'hot', 'phone'],
#  ['accord',
#   'also',
#   'applifi',
#   'call',
#   'everyth',
#   'microphon',
#   'peopl',
#   'well',
#   'work'],
#  ['design', 'nice', 'qualiti'],
#  ['also', 'case', 'drop', 'face', 'go', 'not', 'phone', 'save', 'special'],
#  ['clear', 'easi', 'light', 'recept', 'transmiss', 'use'],
#  ['bad', 'big', 'fit', 'way'],
#  ['definit', 'good', 'not'],
#  ['awesom', 'devic'],
#  ['money', 'wast'],
#  ['cabl',
#   'data',
#   'finish',
#   'got',
#   'motorola',
#   'order',
#   'product',
#   'well',
#   'work'],
#  ['love', 'phone'],
#  ['could', 'got', 'happier', 'headset', 'long', 'look', 'not', 'time'],
#  ['along', 'drivng', 'headset', 'no', 'reason', 'ring', 'start'],
#  ['camera', 'display', 'excel', 'good', 'year'],
#  ['also', 'batteri', 'great', 'life'],
#  ['ever', 'month', 'phone', 'worst'],
#  ['auto',
#   'good',
#   'item',
#   'not',
#   'player',
#   'problem',
#   'revers',
#   'start',
#   'tape',
#   'work'],
#  ['also', 'ear', 'ear', 'embarass', 'hurt', 'plug', 'push', 'tri'],
#  ['phone', 'protect', 'side'],
#  ['averag', 'bad', 'batteri', 'life', 'network', 'oper', 'phone', 'weak'],
#  ['batteri', 'call', 'clear', 'life', 'long', 'rang', 'skype'],
#  ['soyo', 'suck', 'technolog'],
#  ['devic', 'free', 'great', 'hand'],
#  ['cool', 'display', 'even', 'exterior', 'outsid', 'portrait', 'self', 'take'],
#  ['mention', 'other', 'problem'],
#  ['final', 'gadget', 'handsfre', 'mani', 'one', 'tri', 'well', 'work'],
#  ['help', 'magic'],
#  ['along', 'crap', 'custom', 'ever', 'piec', 'servic', 'verizon', 'worst'],
#  ['poor', 'qualiti', 'sound'],
#  ['best', 'market', 'phone'],
#  ['well', 'work'],
#  ['compani', 'product', 'promptli', 'ship', 'well', 'work'],
#  ['exactli', 'want'],
#  ['compar', 'far', 'offer', 'phone', 'pictur', 'price', 'resolut', 'today'],
#  ['deal', 'great'],
#  ['excel', 'product', 'purchas', 'satisfi'],
#  ['encourag', 'give', 'highli', 'peopl', 'recommend', 'tri'],
#  ['better', 'expect', 'would'],
#  ['ear', 'earpiec', 'left', 'not', 'right', 'stay', 'thing', 'use'],
#  ['great', 'price', 'product'],
#  ['effect', 'good', 'price', 'reason', 'simpl', 'sound'],
#  ['ever', 'item', 'reciev', 'still', 'sure', 'wait', 'well', 'work', 'would'],
#  ['disappoint'],
#  ['prompt', 'servic'],
#  ['excel', 'price', 'product'],
#  ['headset', 'pleas'],
#  ['money', 'not', 'time', 'wast'],
#  ['batteri', 'especi', 'life', 'long', 'love'],
#  ['buy',
#   'car',
#   'charger',
#   'come',
#   'cradl',
#   'everi',
#   'headphon',
#   'keep',
#   'kit',
#   'new',
#   'phone',
#   'stupid',
#   'time'],
#  ['great', 'work'],
#  ['bluetooth', 'buy', 'excel', 'plantron'],
#  ['bad',
#   'came',
#   'cell',
#   'cingulair',
#   'first',
#   'nicer',
#   'notic',
#   'phone',
#   'realli',
#   'servic',
#   'thing',
#   'verizon'],
#  ['earpiec', 'look', 'new'],
#  ['devic', 'everyon', 'highli', 'recommend'],
#  ['awesom', 'era', 'jawbon'],
#  ['batteri',
#   'color',
#   'coupl',
#   'dead',
#   'goe',
#   'hoursth',
#   'last',
#   'last',
#   'longer',
#   'origin',
#   'receiv',
#   'still',
#   'thereplac',
#   'use',
#   'week',
#   'white'],
#  ['batteri', 'complet', 'dead', 'headset', 'went', 'year'],
#  ['best', 'one', 'phone', 'sever', 'two', 'use', 'year'],
#  ['awesom', 'fall', 'look', 'new'],
#  ['cheapli', 'first', 'made', 'phone'],
#  ['att', 'clear', 'distort', 'not', 'sound', 'talk', 'yell'],
#  ['break', 'clip', 'easi', 'plastic', 'realli'],
#  ['good', 'price'],
#  ['dont', 'make', 'mistak'],
#  ['also', 'color', 'effect', 'forgot', 'mention', 'oh', 'phone', 'weird'],
#  ['case', 'fine', 'fit', 'iriv', 'spinn', 'use'],
#  ['also', 'area', 'broke', 'fond', 'magnet', 'not', 'strap', 'unit'],
#  ['appoint', 'contact', 'get', 'great', 'overal', 'phone', 'psych', 'recept'],
#  ['everi', 'like', 'perfectli', 'phone', 'thing', 'work'],
#  ['anoth',
#   'appear',
#   'black',
#   'bland',
#   'especi',
#   'look',
#   'model',
#   'note',
#   'phone',
#   'rather',
#   'realli'],
#  ['easi', 'realli'],
#  ['blacktop', 'dozen', 'drop', 'effect', 'ill', 'sanyo', 'surviv', 'without'],
#  ['earphon', 'fantast'],
#  ['away', 'car', 'cell', 'enter', 'find', 'phone', 'right'],
#  ['low', 'qualiti'],
#  ['cellular', 'highli', 'modest', 'phone', 'price', 'recommend'],
#  ['better', 'clariti', 'get', 'phone', 'recept'],
#  ['away', 'stay', 'warn'],
#  ['back', 'could', 'get', 'money', 'return', 'unit', 'wish'],
#  ['awsom', 'devic', 'great', 'work'],
#  ['batteri', 'drain', 'die', 'hour', 'liter', 'talk', 'use', 'would'],
#  ['anyon',
#   'bad',
#   'come',
#   'earpad',
#   'find',
#   'not',
#   'one',
#   'recommend',
#   'unit',
#   'would'],
#  ['displeas'],
#  ['alon',
#   'built',
#   'buy',
#   'defect',
#   'gotten',
#   'might',
#   'not',
#   'qualiti',
#   'risk',
#   'would'],
#  ['case', 'difficult', 'instal', 'made', 'small'],
#  ['like', 'new', 'perform', 'phone', 'restor'],
#  ['figur',
#   'flawlessli',
#   'go',
#   'jabra',
#   'jx',
#   'moto',
#   'purchas',
#   'recommend',
#   'seri',
#   'work',
#   'would'],
#  ['best', 'found', 'internet', 'one', 'search', 'valu'],
#  ['fit', 'not'],
#  ['happi', 'product'],
#  ['big',
#   'camera',
#   'enough',
#   'excel',
#   'key',
#   'lit',
#   'pad',
#   'phone',
#   'qualiti',
#   'screen',
#   'size',
#   'well'],
#  ['bad', 'headset', 'noth', 'realli', 'say', 'there'],
#  ['amazon',
#   'find',
#   'found',
#   'glad',
#   'hard',
#   'high',
#   'not',
#   'price',
#   'product'],
#  ['portabl', 'work'],
#  ['colleagu', 'expens', 'get', 'great', 'littl', 'perform', 'recept'],
#  ['bed',
#   'blue',
#   'charg',
#   'even',
#   'fi',
#   'fulli',
#   'left',
#   'morn',
#   'notic',
#   'tooth',
#   'turn',
#   'went',
#   'wi'],
#  ['also', 'alway', 'card', 'memori', 'phone', 'problem', 'read', 'turn'],
#  ['good', 'hat', 'not', 'sunglass', 'wear'],
#  ['product', 'qualiti', 'shipment', 'time'],
#  ['keyboard', 'nice', 'solid'],
#  ['fit', 'gx', 'made', 'perfectli', 'surefir', 'well'],
#  ['horribl', 'phone'],
#  ['batteri', 'bt', 'junk'],
#  ['other', 'recommend', 'would'],
#  ['cant', 'comput', 'get', 'softwar', 'work'],
#  ['disappoint'],
#  ['clariti', 'poor', 'voic'],
#  ['batteri', 'great', 'work'],
#  ['buyer', 'no', 'one', 'remors'],
#  ['accessoryon', 'disappoint'],
#  ['carrier',
#   'chang',
#   'find',
#   'inexcus',
#   'perhap',
#   'phone',
#   'probabl',
#   'return'],
#  ['great', 'look', 'strong'],
#  ['happi', 'pretti', 'servic', 'tmobil', 'year'],
#  ['cumbersom', 'difficult', 'procedur', 'updat'],
#  ['anyth', 'disappoint', 'ear', 'goe', 'hate'],
#  ['great', 'motorola', 'softwar'],
#  ['deliveri', 'time'],
#  ['easi', 'use'],
#  ['dont', 'ear', 'env', 'lg', 'uncomfort', 'use', 'vx'],
#  ['destin', 'rocket', 'switch', 'unit', 'unknown', 'volum'],
#  ['charg',
#   'comfort',
#   'condit',
#   'hold',
#   'long',
#   'qualiti',
#   'reason',
#   'sound',
#   'time',
#   'tremend',
#   'wear'],
#  ['like', 'return', 'would'],
#  ['enough',
#   'expect',
#   'keyboard',
#   'not',
#   'problem',
#   'realli',
#   'sturdi',
#   'use',
#   'worthwhil'],
#  ['bill',
#   'difficult',
#   'even',
#   'howev',
#   'plan',
#   'price',
#   'simpl',
#   'though',
#   'understand',
#   'verizon'],
#  ['batteri', 'charg', 'great', 'overnight', 'work'],
#  ['not', 'regret'],
#  ['love', 'phone'],
#  ['disappoint'],
#  ['friendli', 'not', 'user'],
#  ['abil',
#   'actual',
#   'call',
#   'featur',
#   'import',
#   'know',
#   'phone',
#   'piti',
#   'rather',
#   'receiv',
#   'respect',
#   'unfortun'],
#  ['even', 'exchang', 'phone', 'problem'],
#  ['either', 'max', 'mute', 'phone', 'result', 'stuck', 'volum'],
#  ['pda', 'rock'],
#  ['camera',
#   'cellphon',
#   'charg',
#   'excel',
#   'hybrid',
#   'palmtop',
#   'role',
#   'small',
#   'super',
#   'use'],
#  ['btv',
#   'clariti',
#   'comfort',
#   'definit',
#   'great',
#   'jabra',
#   'look',
#   'price',
#   'recommend',
#   'would'],
#  ['ago', 'like', 'realli', 'servic', 'verizon', 'year'],
#  ['junk', 'piec', 'pretti'],
#  ['plug', 'size', 'wrong'],
#  ['describ', 'work'],
#  ['item', 'money', 'month', 'save'],
#  ['bad', 'purchas'],
#  ['im', 'satisfi', 'well'],
#  ['amaz', 'bose', 'cancel', 'commut', 'import', 'nois', 'nyc'],
#  ['bargain', 'batteri', 'excel'],
#  ['crap', 'defect'],
#  ['abl', 'given', 'no', 'star', 'would'],
#  ['fine', 'fit', 'glass', 'wear'],
#  ['almost',
#   'area',
#   'devic',
#   'hear',
#   'noth',
#   'qualiti',
#   'quiet',
#   'realli',
#   'sound',
#   'unaccept',
#   'unless'],
#  ['anyon', 'item', 'not', 'recommend', 'would'],
#  ['ad', 'arriv', 'holster', 'match', 'not', 'photo'],
#  ['great', 'no', 'problem'],
#  ['charger', 'earlier', 'happen', 'note', 'noth', 'plug', 'review'],
#  ['ador', 'catch', 'charm', 'eye', 'frog', 'phone'],
#  ['enough',
#   'function',
#   'hard',
#   'know',
#   'never',
#   'not',
#   'number',
#   'push',
#   'right',
#   'time',
#   'want'],
#  ['amaz', 'clear', 'peopl', 'qualiti', 'sound', 'talk'],
#  ['aluminum',
#   'case',
#   'far',
#   'got',
#   'handheld',
#   'new',
#   'palm',
#   'perfectli',
#   'protect',
#   'realli',
#   'vx',
#   'well',
#   'work'],
#  ['good', 'made', 'product', 'well'],
#  ['mobil', 'must', 'phone', 'tool'],
#  ['impress', 'job', 'motorola', 'phone', 'sturdi'],
#  ['everyth',
#   'excit',
#   'good',
#   'order',
#   'order',
#   'overal',
#   'receiv',
#   'ship',
#   'sourc',
#   'timefram',
#   'well',
#   'within',
#   'work'],
#  ['phone', 'sturdi', 'waterproof'],
#  ['anyon', 'impress', 'item', 'not', 'recommend', 'would'],
#  ['complaint', 'even', 'littl', 'low', 'sound', 'standard', 'turn', 'volum'],
#  ['amazon', 'good', 'need', 'price', 'thank', 'thing'],
#  ['back', 'edg', 'end', 'instead', 'pant', 'pocket', 'slide'],
#  ['bought', 'go', 'great', 'new', 'nokia', 'phone', 'store', 'work'],
#  ['great', 'work'],
#  ['realli', 'ugli'],
#  ['horribl', 'switch', 'time'],
#  ['incredi', 'nois', 'shield'],
#  ['improv', 'no', 'real'],
#  ['batteri', 'buy', 'good', 'razr'],
#  ['amazon', 'good', 'keep', 'work'],
#  ['refund', 'refus', 'replac'],
#  ['accident',
#   'activ',
#   'button',
#   'easi',
#   'face',
#   'gentl',
#   'listen',
#   'phone',
#   'touch',
#   'unfortun'],
#  ['basic', 'money', 'noth', 'threw', 'window'],
#  ['case', 'great', 'price'],
#  ['counter',
#   'crack',
#   'drop',
#   'impress',
#   'inch',
#   'kitchen',
#   'laugh',
#   'not',
#   'one',
#   'took'],
#  ['ago',
#   'bluetooth',
#   'call',
#   'carri',
#   'convers',
#   'day',
#   'good',
#   'got',
#   'hitch',
#   'left',
#   'phone',
#   'rang',
#   'trunk',
#   'without'],
#  ['ampl',
#   'impress',
#   'look',
#   'place',
#   'practic',
#   'setup',
#   'sleek',
#   'small',
#   'storag'],
#  ['channel',
#   'clariti',
#   'directli',
#   'ear',
#   'eargel',
#   'increas',
#   'seem',
#   'sound',
#   'volum'],
#  ['ever', 'new', 'none', 'one', 'properli', 'quit', 'work'],
#  ['glad', 'purchas'],
#  ['call', 'miss', 'numer', 'reason'],
#  ['cannot', 'defect', 'hear', 'peopl', 'perhap', 'phone', 'use'],
#  ['buy', 'dont', 'product'],
#  ['not', 'phone', 'stuff', 'suck', 'work'],
#  ['bubbl',
#   'could',
#   'droid',
#   'even',
#   'happier',
#   'new',
#   'no',
#   'not',
#   'nothingi',
#   'one',
#   'peel',
#   'scratch',
#   'shift'],
#  ['could', 'ever', 'give', 'softwar', 'star', 'use', 'worst', 'would', 'zero'],
#  ['call', 'exercis', 'frustrat', 'make', 'tri'],
#  ['case',
#   'flimsi',
#   'front',
#   'no',
#   'piec',
#   'plastic',
#   'protect',
#   'side',
#   'whatsoev'],
#  ['better', 'earset', 'especi', 'happi', 'jabra', 'outgo', 'qualiti', 'sound'],
#  ['camera', 'good', 'love', 'pretti', 'qualiti', 'realli'],
#  ['great', 'servic', 'thank'],
#  ['packag', 'total'],
#  ['buy', 'definit', 'patient', 'seller', 'understand', 'would'],
#  ['att',
#   'cingular',
#   'contact',
#   'give',
#   'inform',
#   'practic',
#   'star',
#   'wirefli'],
#  ['aggrav'],
#  ['great', 'price', 'product'],
#  ['clariti', 'eas', 'enjoy', 'famili', 'friend', 'purchas', 'use'],
#  ['cheap', 'littl', 'phone', 'rock', 'virgin', 'wireless'],
#  ['buy', 'none', 'not', 'work'],
#  ['around',
#   'case',
#   'glu',
#   'insert',
#   'low',
#   'muddi',
#   'poorli',
#   'qualiti',
#   'slid',
#   'sound',
#   'super',
#   'wire'],
#  ['dont', 'money', 'pleas', 'wast'],
#  ['purchas', 'quit', 'satisfi'],
#  ['good', 'headset', 'keep', 'look', 'motorola', 'not', 'qualiti'],
#  ['charger', 'continu', 'design', 'flaw', 'plantroninc', 'use', 'yet'],
#  ['disapoint', 'result'],
#  ['cumbersom', 'design'],
#  ['came',
#   'expect',
#   'good',
#   'great',
#   'less',
#   'new',
#   'nice',
#   'no',
#   'packag',
#   'problem',
#   'time',
#   'work'],
#  ['great', 'product'],
#  ['crap', 'piec'],
#  ['bluetooth',
#   'comfort',
#   'experi',
#   'fourth',
#   'hate',
#   'headset',
#   'jabra',
#   'last',
#   'much',
#   'terribl'],
#  ['fix', 'problem'],
#  ['ever', 'worst'],
#  ['happi'],
#  ['access',
#   'download',
#   'function',
#   'internet',
#   'no',
#   'perform',
#   'rington',
#   'troubl'],
#  ['bare', 'constantli', 'ever', 'hear', 'say'],
#  ['batteri', 'highli', 'life', 'unaccept'],
#  ['compani', 'joke'],
#  ['descript', 'everyth', 'said', 'would'],
#  ['call', 'due', 'everi', 'forc', 'happen', 'headset', 'stop', 'use'],
#  ['adapt',
#   'cannot',
#   'car',
#   'charger',
#   'especi',
#   'great',
#   'plug',
#   'time',
#   'two',
#   'work'],
#  ['data',
#   'end',
#   'hard',
#   'none',
#   'procedur',
#   'set',
#   'support',
#   'tech',
#   'verizon',
#   'walk',
#   'wipe',
#   'work'],
#  ['call', 'drop', 'qualiti', 'signal', 'strength', 'voic'],
#  ['howev',
#   'lack',
#   'louder',
#   'low',
#   'not',
#   'play',
#   'price',
#   'qualiti',
#   'size',
#   'speaker',
#   'think',
#   'would'],
#  ['better', 'expect'],
#  ['button',
#   'construct',
#   'difficult',
#   'feel',
#   'menu',
#   'navig',
#   'poorli',
#   'push',
#   'recess'],
#  ['batteri', 'hold', 'well'],
#  ['also', 'avoid', 'difficult', 'id', 'product', 'put', 'recommend'],
#  ['alway', 'day', 'easi', 'hear', 'not', 'two', 'use'],
#  ['broken',
#   'car',
#   'charger',
#   'even',
#   'got',
#   'not',
#   'plug',
#   'smoke',
#   'start',
#   'week',
#   'went'],
#  ['custom', 'servic', 'sprint', 'terribl'],
#  ['effort', 'link', 'phone', 'without'],
#  ['cool'],
#  ['easi', 'use'],
#  ['better', 'new'],
#  ['get', 'idea', 'junk', 'no', 'posses'],
#  ['piec', 'trash'],
#  ['good', 'pretti', 'product'],
#  ['great', 'phone'],
#  ['amazon', 'excel', 'highli', 'price', 'product', 'recommend', 'would'],
#  ['develop', 'divis', 'know', 'obvious', 'research'],
#  ['break', 'cours', 'killer', 'real', 'volum'],
#  ['fine', 'phone', 'work'],
#  ['happi', 'product'],
#  ['construct', 'poor'],
#  ['infuri'],
#  ['new', 'overal', 'phone', 'recommend', 'walkman', 'would'],
#  ['charg', 'servic', 'sprint'],
#  ['cheap', 'feel', 'look'],
#  ['comfort', 'ear', 'fit', 'well'],
#  ['asia', 'europ', 'not', 'work'],
#  ['belt', 'cent', 'clip', 'come', 'deffinit', 'feel', 'like', 'make'],
#  ['behe',
#   'comfort',
#   'day',
#   'design',
#   'ear',
#   'headset',
#   'hour',
#   'jabra',
#   'like',
#   'look',
#   'pain',
#   'pretti',
#   'wear',
#   'without'],
#  ['amaz',
#   'arriv',
#   'batteri',
#   'cell',
#   'fraction',
#   'lg',
#   'origin',
#   'phone',
#   'price',
#   'quick',
#   'two'],
#  ['crap', 'crappi', 'ever', 'phone', 'samsung', 'seeen', 'worst'],
#  ['charger', 'charg', 'complet', 'phone', 'stop', 'week', 'work'],
#  ['poor', 'product'],
#  ['better', 'howev', 'instruct', 'need'],
#  ['cannot',
#   'compet',
#   'decad',
#   'design',
#   'hand',
#   'interfac',
#   'need',
#   'new',
#   'old',
#   'oper',
#   'screen',
#   'softwar',
#   'two'],
#  ['bluetooth',
#   'headset',
#   'pair',
#   'pc',
#   'skype',
#   'transceiv',
#   'treo',
#   'usb',
#   'use',
#   'well',
#   'work'],
#  ['clear',
#   'come',
#   'genuin',
#   'go',
#   'pack',
#   'palm',
#   'pen',
#   'product',
#   'replacementr',
#   'steer',
#   'three'],
#  ['buy', 'buyit', 'not', 'suck'],
#  ['beat', 'finger', 'great', 'product', 'sure', 'use'],
#  ['believ', 'not', 'plu', 'point', 'price', 'serious', 'steep', 'worth'],
#  ['apart',
#   'case',
#   'fall',
#   'haul',
#   'long',
#   'month',
#   'normal',
#   'one',
#   'seem',
#   'tri'],
#  ['dissapoint', 'perform'],
#  ['buy', 'dont', 'make', 'mistak', 'not', 'phone', 'pleas'],
#  ['brand', 'ever', 'might', 'phone', 'well', 'worst'],
#  ['case',
#   'discard',
#   'ear',
#   'extra',
#   'later',
#   'less',
#   'origin',
#   'put',
#   'scratch'],
#  ['anyon',
#   'brand',
#   'cell',
#   'differ',
#   'famili',
#   'igo',
#   'mp',
#   'phone',
#   'player',
#   'recommend'],
#  ['bother', 'dont', 'go', 'store'],
#  ['black',
#   'color',
#   'comment',
#   'detail',
#   'fire',
#   'great',
#   'grey',
#   'phone',
#   'post',
#   'red'],
#  ['item', 'need', 'not', 'order', 'problem', 'would'],
#  ['get', 'guess', 'pay'],
#  ['also',
#   'cd',
#   'connect',
#   'could',
#   'exist',
#   'form',
#   'great',
#   'internet',
#   'job',
#   'make',
#   'not',
#   'rington',
#   'softwar',
#   'without'],
#  ['car',
#   'charger',
#   'good',
#   'im',
#   'much',
#   'not',
#   'qualiti',
#   'review',
#   'surpris'],
#  ['fabul'],
#  ['audio',
#   'bt',
#   'current',
#   'delay',
#   'first',
#   'game',
#   'good',
#   'headset',
#   'howev',
#   'like',
#   'mess',
#   'not',
#   'person',
#   'real',
#   'shooter',
#   'sinc',
#   'time'],
#  ['bitpim',
#   'cabl',
#   'data',
#   'excel',
#   'find',
#   'free',
#   'internetto',
#   'phone',
#   'price',
#   'program',
#   'transfer',
#   'use'],
#  ['accessori', 'disappoint', 'good', 'manufactur'],
#  ['aw',
#   'call',
#   'echo',
#   'end',
#   'incom',
#   'muffl',
#   'perform',
#   'sever',
#   'sound',
#   'tinni'],
#  ['resist', 'wind'],
#  ['custom', 'get', 'obvious', 'pay', 'servic', 'terribl'],
#  ['better',
#   'easi',
#   'expens',
#   'forev',
#   'last',
#   'much',
#   'not',
#   'oper',
#   'other',
#   'overli',
#   'replac',
#   'sound',
#   'tri'],
#  ['although',
#   'compani',
#   'contact',
#   'could',
#   'luck',
#   'not',
#   'produc',
#   'receipt',
#   'still',
#   'told',
#   'unit',
#   'warranti'],
#  ['bad', 'exchang', 'linksi', 'phone', 'refurb', 'someth', 'unit', 'way'],
#  ['bar', 'nokia', 'phone', 'phone', 'sturdi'],
#  ['great', 'phone'],
#  ['case', 'extra', 'lot', 'not', 'place', 'room', 'side', 'snug', 'treo'],
#  ['pleas'],
#  ['batteri', 'terribl'],
#  ['easi', 'found', 'product', 'set', 'use'],
#  ['ear', 'earpiec', 'fall', 'heavi', 'keep', 'larg'],
#  ['crap', 'qualiti', 'sound', 'terribl', 'utter'],
#  ['arriv', 'charger', 'not', 'promis', 'timefram', 'within', 'work'],
#  ['ear', 'great', 'loop', 'need', 'no', 'sound', 'tini'],
#  ['broke',
#   'could',
#   'final',
#   'four',
#   'latch',
#   'longer',
#   'not',
#   'spring',
#   'three',
#   'time',
#   'use',
#   'visor'],
#  ['address',
#   'book',
#   'car',
#   'devic',
#   'download',
#   'fine',
#   'handsfre',
#   'high',
#   'overal',
#   'part',
#   'rate',
#   'reboot',
#   'still',
#   'treo',
#   'tri',
#   'work'],
#  ['custom', 'servic', 'talk', 'useless'],
#  ['felt', 'light', 'tinni'],
#  ['broke', 'first', 'fit', 'not', 'palm', 'plug', 'time', 'tri', 'tungsten'],
#  ['good', 'happi', 'low', 'price', 'purchas', 'qualiti'],
#  ['feel', 'flipphon', 'look', 'love', 'samsung'],
#  ['blue', 'color', 'design', 'nice', 'sharp', 'well'],
#  ['everyth'],
#  ['could', 'not', 'recommend'],
#  ['nice', 'sound'],
#  ['case', 'disappoint', 'good', 'huge', 'look', 'pictur'],
#  ['go', 'jawbon', 'less', 'much', 'replac'],
#  ['setup', 'smoothli', 'went'],
#  ['anyth', 'extrem', 'forev', 'slow', 'take'],
#  ['anyon', 'design', 'industri', 'interest', 'must', 'sin', 'studi', 'worst'],
#  ['first', 'happen', 'thing', 'track'],
#  ['access',
#   'belt',
#   'clip',
#   'detach',
#   'easi',
#   'handi',
#   'made',
#   'phone',
#   'well'],
#  ['continu', 'drop', 'kept', 'pair', 'period', 'sinc', 'somehow'],
#  ['cant', 'parti', 'rington', 'third', 'upload'],
#  ['bluetooth',
#   'call',
#   'flash',
#   'lock',
#   'lock',
#   'make',
#   'not',
#   'phone',
#   'pocket',
#   'randomli',
#   'screen',
#   'work'],
#  ['aw', 'truli'],
#  ['batteri', 'better', 'cellphon', 'fine', 'lot', 'motorola', 'work', 'worn'],
#  ['choic', 'good', 'loud', 'real', 'ringer', 'volum'],
#  ['accept', 'none', 'tone'],
#  ['aw', 'balanc', 'camera', 'color'],
#  ['call',
#   'cannot',
#   'care',
#   'clearli',
#   'come',
#   'cool',
#   'look',
#   'not',
#   'prime',
#   'product',
#   'readi',
#   'tell',
#   'time',
#   'worthless'],
#  ['love', 'rington', 'upbeat'],
#  ['abound', 'chines', 'forgeri'],
#  ['cell', 'easi', 'pair', 'samsung'],
#  ['could', 'explain', 'instruct', 'jack', 'microphon', 'not', 'use'],
#  ['advis', 'item', 'never', 'not', 'purchas', 'well', 'work', 'would'],
#  ['bad', 'month', 'pay', 'servic'],
#  ['well', 'work'],
#  ['ca', 'cabl', 'nokia', 'not', 'phone', 'usb', 'work'],
#  ['clear', 'crisp', 'sound'],
#  ['earpiec', 'pretti', 'provid', 'smallest', 'stay', 'use', 'well'],
#  ['batteri', 'biggest', 'complaint', 'drain', 'superfast'],
#  ['could', 'design', 'ear', 'ergonom', 'might', 'not', 'stand', 'theori'],
#  ['buy', 'holster', 'not', 'use', 'want'],
#  ['also', 'clip', 'even', 'great', 'phone', 'pictur', 'take', 'video'],
#  ['cool', 'look', 'make', 'not'],
#  ['background', 'distract', 'ear', 'not', 'occupi'],
#  ['comfort',
#   'day',
#   'entir',
#   'fit',
#   'headset',
#   'hour',
#   'least',
#   'need',
#   'not',
#   'time'],
#  ['accept',
#   'also',
#   'anyth',
#   'cbr',
#   'except',
#   'media',
#   'mp',
#   'not',
#   'phone',
#   'player',
#   'prefer',
#   'rip',
#   'seem',
#   'window'],
#  ['beat', 'cannot', 'price'],
#  ['camera',
#   'come',
#   'even',
#   'flash',
#   'light',
#   'serious',
#   'shot',
#   'signal',
#   'so',
#   'strong',
#   'use'],
#  ['lightweight', 'well', 'work'],
#  ['bewar'],
#  ['allow', 'cabl', 'connect', 'devic', 'love', 'mini', 'pc', 'usb'],
#  ['anyon', 'convers', 'hear', 'near', 'part'],
#  ['allow', 'case', 'cool', 'get', 'open', 'scratch', 'screen'],
#  ['bought', 'phone', 'regret', 'replac', 'sinc', 'startac'],
#  ['actual',
#   'appear',
#   'batteri',
#   'came',
#   'china',
#   'origin',
#   'outperform',
#   'vi'],
#  ['anyth', 'cant', 'number', 'phone', 'sim', 'store'],
#  ['actual', 'last', 'less', 'minut', 'phone', 'problem', 'tri', 'use', 'wife'],
#  ['poor', 'qualiti'],
#  ['best', 'ear', 'gel', 'jabra'],
#  ['not', 'worth'],
#  ['complet', 'crash', 'get', 'phone', 'replac'],
#  ['anoth',
#   'best',
#   'ever',
#   'headset',
#   'month',
#   'one',
#   'own',
#   'purchas',
#   'quit',
#   'use',
#   'work',
#   'would'],
#  ['batteri',
#   'connect',
#   'despit',
#   'etc',
#   'extern',
#   'imac',
#   'iphon',
#   'multipl',
#   'not',
#   'outlet',
#   'power',
#   'recharg',
#   'sourc',
#   'unfortun',
#   'wall'],
#  ['great', 'phone'],
#  ['bell',
#   'elsewher',
#   'extra',
#   'flip',
#   'look',
#   'mediocr',
#   'phone',
#   'simpli',
#   'small',
#   'want',
#   'whistl'],
#  ['car',
#   'fine',
#   'good',
#   'outlet',
#   'power',
#   'usb',
#   'valu',
#   'via',
#   'wall',
#   'work'],
#  ['around', 'car', 'grip', 'hand', 'not', 'phone', 'prevent', 'slide', 'slip'],
#  ['best', 'bluetooth', 'headset', 'qualiti', 'simpli', 'sound'],
#  ['last', 'moto', 'onethi', 'phone', 'plan', 'sure', 'think'],
#  ['exclaim', 'hour', 'new', 'peopl', 'phone', 'span', 'tv', 'two', 'whoa'],
#  ['alway', 'cord', 'freedom', 'headset', 'help', 'use', 'wireless'],
#  ['case', 'function', 'mark', 'one', 'pass', 'show', 'sign', 'wear', 'year'],
#  ['cut', 'face', 'fit', 'good', 'leather', 'nice', 'shape', 'soft', 'tight'],
#  ['ask', 'could', 'everyth', 'need', 'not'],
#  ['broke', 'day', 'product', 'receiv', 'use'],
#  ['copier',
#   'easier',
#   'go',
#   'great',
#   'hold',
#   'lot',
#   'make',
#   'product',
#   'someth',
#   'wait',
#   'work'],
#  ['ear', 'headset', 'none', 'sent', 'size', 'stay', 'three', 'would'],
#  ['anywher', 'best', 'custom', 'mobil', 'servic'],
#  ['arriv', 'expens', 'less', 'much', 'other', 'quickli', 'sold'],
#  ['fail', 'month', 'pro', 'tri', 'unit', 'within'],
#  ['classi', 'good', 'look', 'protect', 'provid'],
#  ['alway', 'good', 'krussel'],
#  ['easi', 'etc', 'friendli', 'make', 'toactiv', 'tracfonewebsit', 'user'],
#  ['design', 'good'],
#  ['great', 'recept', 'time'],
#  ['highli', 'product', 'recommend', 'would'],
#  ['couldnt', 'good', 'not', 'sunglass', 'texa', 'unit', 'use'],
#  ['dit', 'nokia', 'not', 'time', 'work'],
#  ['bought', 'broke', 'charger', 'mainli', 'purchas', 'soon'],
#  ['buzz', 'convers', 'like', 'loud', 'overrid', 'phone'],
#  ['buy', 'fantast', 'get', 'next', 'phone', 'whatev'],
#  ['away', 'care', 'stay', 'store'],
#  ['awesom', 'blueant', 'free', 'hand', 'phone', 'speaker', 'supertooth'],
#  ['fit', 'not'],
#  ['arriv',
#   'ear',
#   'great',
#   'item',
#   'metro',
#   'pc',
#   'phone',
#   'plug',
#   'premium',
#   'quickli',
#   'samsung',
#   'sch',
#   'slider',
#   'soni',
#   'sound',
#   'work'],
#  ['batteri',
#   'capac',
#   'confort',
#   'extend',
#   'light',
#   'period',
#   'plenti',
#   'somewhat',
#   'time',
#   'wear'],
#  ['disappoint'],
#  ['ant', 'blue', 'easi', 'use'],
#  ['cheap',
#   'cost',
#   'given',
#   'hey',
#   'item',
#   'low',
#   'pleasantli',
#   'supris',
#   'work'],
#  ['camera',
#   'dispos',
#   'dustpan',
#   'indoor',
#   'may',
#   'phone',
#   'rather',
#   'use',
#   'use',
#   'would'],
#  ['came', 'day', 'later', 'phone', 'puff', 'smoke', 'use'],
#  ['car',
#   'conveni',
#   'done',
#   'get',
#   'job',
#   'make',
#   'much',
#   'ride',
#   'simpl',
#   'smoother',
#   'use'],
#  ['dissapoint', 'nano', 'son', 'state'],
#  ['excel', 'qualiti', 'sound', 'well'],
#  ['best', 'headset', 'use'],
#  ['not', 'reccommend', 'would'],
#  ['anti',
#   'around',
#   'carri',
#   'date',
#   'found',
#   'glare',
#   'highest',
#   'protector',
#   'qualiti',
#   'screen',
#   'year'],
#  ['want'],
#  ['model', 'motorola', 'not', 'particular', 'smartphon', 'work', 'would'],
#  ['atleast', 'right', 'wont', 'work'],
#  ['addit', 'amp', 'cheap', 'feel', 'lightweight', 'look', 'phone', 'plastic'],
#  ['bottom',
#   'cingular',
#   'els',
#   'line',
#   'money',
#   'not',
#   'problem',
#   'put',
#   'reoccur',
#   'somewher',
#   'support',
#   'warranti'],
#  ['good', 'issu', 'mani', 'one', 'plantron', 'realli', 'right', 'want'],
#  ['great', 'product'],
#  ['clear', 'crisp'],
#  ['charg', 'dead', 'first', 'go', 'kept', 'minut'],
#  ['cheap', 'creak', 'floor', 'like', 'old', 'plastic', 'wooden'],
#  ['absolut', 'apart', 'get', 'horribl', 'not', 'phone', 'problem', 'recept'],
#  ['gener', 'good', 'recept'],
#  ['batteri', 'boot', 'excel', 'inconspicu', 'life', 'sound'],
#  ['bluetooth', 'great'],
#  ['case', 'highli', 'recommend'],
#  ['worthwhil'],
#  ['deal', 'great'],
#  ['break',
#   'care',
#   'despit',
#   'got',
#   'much',
#   'old',
#   'part',
#   'phone',
#   'slowli',
#   'year'],
#  ['made', 'purchas', 'sorri'],
#  ['better',
#   'bluetooth',
#   'bought',
#   'could',
#   'fit',
#   'headset',
#   'hope',
#   'imposs',
#   'made',
#   'make',
#   'thing',
#   'wear'],
#  ['anoth',
#   'buy',
#   'discount',
#   'forc',
#   'kind',
#   'mobil',
#   'phone',
#   'refus',
#   'replac',
#   'treo',
#   'upgrad',
#   'without'],
#  ['horribl'],
#  ['belt', 'hold', 'not', 'securli', 'think', 'would'],
#  ['allow', 'book', 'date', 'doubl', 'first', 'possibl', 'time'],
#  ['break', 'week', 'work'],
#  ['like', 'simpl', 'use'],
#  ['activesync',
#   'commun',
#   'data',
#   'entertain',
#   'great',
#   'manag',
#   'oh',
#   'optim',
#   'result',
#   'sure',
#   'synchron',
#   'tool',
#   'use'],
#  ['cannot', 'case', 'disgust', 'smell', 'use'],
#  ['not', 'want'],
#  ['anoth', 'case', 'order', 'would'],
#  ['great', 'phone'],
#  ['amazon', 'batteri', 'bought', 'coupon', 'happi', 'purchas'],
#  ['access', 'fine', 'instanc', 'internet', 'rare', 'work'],
#  ['perfect', 'ps'],
#  ['five', 'plu', 'star'],
#  ['aw',
#   'bargain',
#   'big',
#   'bought',
#   'cheapi',
#   'could',
#   'end',
#   'good',
#   'hear',
#   'lot',
#   'not',
#   'peopl',
#   'qualiti',
#   'sound'],
#  ['drain'],
#  ['get',
#   'great',
#   'loud',
#   'not',
#   'old',
#   'real',
#   'shout',
#   'still',
#   'talk',
#   'telephon',
#   'told',
#   'tri'],
#  ['fine', 'good', 'work'],
#  ['deal', 'great', 'price'],
#  ['great', 'price'],
#  ['complet', 'useless', 'wind'],
#  ['front', 'love', 'shini', 'side', 'ye'],
#  ['not', 'work'],
#  ['deal',
#   'first',
#   'good',
#   'grtting',
#   'phone',
#   'plug',
#   'razr',
#   'thought',
#   'vc'],
#  ['excel', 'headset', 'recept'],
#  ['seller', 'thumb'],
#  ['exce',
#   'feet',
#   'good',
#   'lg',
#   'line',
#   'phone',
#   'rang',
#   'recept',
#   'sight',
#   'togeth',
#   'verizon',
#   'well',
#   'work'],
#  ['descript', 'improp', 'return'],
#  ['comfort', 'work'],
#  ['batteri', 'charg', 'life', 'long', 'quit'],
#  ['eargel', 'ear', 'fit', 'jabra', 'well'],
#  ['batteri', 'life', 'no'],
#  ['check', 'disappoint', 'everywher', 'featur', 'no', 'realli'],
#  ['describ', 'exactli', 'product'],
#  ['get', 'phone', 'signal', 'verizon', 'wont'],
#  ['doesnt', 'job'],
#  ['recommend', 'would'],
#  ['order', 'plan'],
#  ['camera',
#   'cool',
#   'decent',
#   'effect',
#   'mani',
#   'nice',
#   'phone',
#   'play',
#   'said',
#   'video',
#   'well'],
#  ['cell', 'day', 'one', 'phone', 'satisfi'],
#  ['better', 'get', 'keep', 'numer', 'one', 'palm', 'third'],
#  ['awkward', 'unreli', 'use'],
#  ['also', 'quick', 'ship', 'time'],
#  ['good', 'hope', 'not'],
#  ['case', 'good'],
#  ['doesnt', 'work'],
#  ['good', 'product', 'realli'],
#  ['not', 'unfortun', 'work'],
#  ['broke', 'month', 'three', 'two', 'use', 'within'],
#  ['buy', 'dont'],
#  ['batteri', 'die', 'father'],
#  ['come', 'ear', 'easili', 'howev', 'lost', 'one', 'pad', 'week'],
#  ['black',
#   'call',
#   'come',
#   'drop',
#   'goe',
#   'intermitt',
#   'phone',
#   'ring',
#   'screen',
#   'stop',
#   'worst'],
#  ['horribl', 'protector'],
#  ['either', 'like', 'nokia', 'not'],
#  ['bottom',
#   'end',
#   'expect',
#   'key',
#   'not',
#   'reach',
#   'row',
#   'send',
#   'uncomfort'],
#  ['ago', 'bought', 'cell', 'nightmar', 'nokia', 'phone', 'week'],
#  ['amazon',
#   'bad',
#   'custom',
#   'describ',
#   'experi',
#   'long',
#   'servic',
#   'take',
#   'would'],
#  ['disappoint', 'no', 'speakerphon', 'thing'],
#  ['accept', 'car', 'cassett', 'not', 'terribl'],
#  ['cellphon',
#   'charg',
#   'charg',
#   'current',
#   'enough',
#   'not',
#   'plan',
#   'product',
#   'sinc',
#   'use',
#   'useless'],
#  ['not', 'say'],
#  ['away', 'stay'],
#  ['dirti', 'use'],
#  ['mobil', 'servic', 'unreli'],
#  ['enough', 'good', 'not', 'price'],
#  ['bought', 'charg', 'neither', 'two'],
#  ['look', 'nice'],
#  ['answer', 'auto', 'especi', 'excel', 'pair', 'phone', 'tool'],
#  ['not', 'other', 'problem', 'read', 'review'],
#  ['cover', 'ear', 'import', 'light', 'outlet', 'product', 'sensor'],
#  ['comfort', 'hand'],
#  ['not', 'work'],
#  ['poor', 'reliabl'],
#  ['work'],
#  ['bar',
#   'batteri',
#   'beep',
#   'die',
#   'drop',
#   'know',
#   'let',
#   'pictur',
#   'start',
#   'take'],
#  ['money', 'product', 'terribl', 'wast'],
#  ['buy', 'last', 'time'],
#  ['money', 'wast'],
#  ['charm', 'far', 'like', 'work'],
#  ['far', 'good', 'week'],
#  ['best',
#   'case',
#   'download',
#   'even',
#   'ir',
#   'laptop',
#   'part',
#   'phone',
#   'pictur',
#   'send',
#   'use'],
#  ['item', 'recommend', 'would'],
#  ['cancel',
#   'choic',
#   'good',
#   'great',
#   'headset',
#   'nois',
#   'sound',
#   'volum',
#   'year'],
#  ['case', 'feel', 'good', 'hand', 'nice'],
#  ['counterfeit', 'item', 'receiv'],
#  ['best', 'bt', 'ever', 'far', 'good', 'headset', 'probabl', 'realli'],
#  ['fine', 'work'],
#  ['good', 'happi', 'headset', 'receiv', 'time'],
#  ['blackberri',
#   'could',
#   'flip',
#   'holster',
#   'pleas',
#   'replac',
#   'see',
#   'swivel',
#   'travl',
#   'well'],
#  ['also', 'love', 'one', 'sister'],
#  ['good', 'qualiti'],
#  ['amazon', 'far', 'made', 'purchas', 'worst'],
#  ['dual', 'excel', 'headset', 'purpos'],
#  ['excel'],
#  ['cingular', 'listen', 'music', 'not', 'work'],
#  ['belt', 'complet', 'hold', 'insid', 'iphon', 'keep', 'secur', 'seem'],
#  ['anoth', 'bottowm', 'cheap', 'gimmick', 'line', 'sprint', 'worthless'],
#  ['troubl', 'volum'],
#  ['comfort', 'ear', 'fit', 'good', 'small', 'thing'],
#  ['buy', 'not', 'warn'],
#  ['could', 'far', 'happier', 'iphon', 'not', 'pair'],
#  ['batteri', 'broken', 'connect', 'devic', 'open', 'turn'],
#  ['caus', 'clip', 'discomfort', 'ear', 'go', 'not', 'top', 'want'],
#  ['best', 'ever', 'headset'],
#  ['dont', 'expect', 'help', 'not', 'support', 'trust', 'websit'],
#  ['cell',
#   'connect',
#   'flawless',
#   'glad',
#   'loud',
#   'maintain',
#   'no',
#   'normal',
#   'plantron',
#   'say',
#   'static',
#   'use'],
#  ['cheap', 'low', 'make', 'qualiti', 'ring', 'sound', 'speaker', 'tone'],
#  ['came', 'comfort', 'earbud', 'fit', 'size', 'three', 'tip'],
#  ['excel', 'price', 'product'],
#  ['bad', 'recept'],
#  ['chines', 'crap', 'high', 'product', 'qualiti'],
#  ['comfort', 'ear', 'quit'],
#  ['great', 'phone'],
#  ['buy', 'dont', 'fail', 'product'],
#  ['everyth', 'first', 'product', 'wrong'],
#  ['bare',
#   'call',
#   'coupl',
#   'devic',
#   'dial',
#   'easi',
#   'featur',
#   'make',
#   'minut',
#   'pair',
#   'start',
#   'took',
#   'two',
#   'voic'],
#  ['caus', 'confus', 'contact', 'coupl', 'first', 'import', 'lose', 'utterli'],
#  ['holder', 'phone', 'terribl'],
#  ['button', 'cutout', 'perfectli', 'place'],
#  ['abl', 'cell', 'headset', 'land', 'line', 'love', 'one', 'use'],
#  ['break', 'ear', 'easili', 'loop', 'made', 'materi', 'problem', 'weak'],
#  ['amazon', 'good', 'look', 'look', 'make', 'nearli', 'not', 'pictur'],
#  ['addit',
#   'case',
#   'cost',
#   'despit',
#   'except',
#   'flaw',
#   'oem',
#   'offici',
#   'own',
#   'product',
#   'qualiti',
#   'well',
#   'worth'],
#  ['stupid'],
#  ['car', 'drive', 'even', 'hear', 'loudest', 'not', 'put', 'set', 'usual'],
#  ['cheaper', 'competitor', 'much', 'quickli', 'seller', 'ship'],
#  ['good', 'samsung', 'show'],
#  ['alot', 'bought', 'money', 'save'],
#  ['alway', 'beep', 'cut', 'fail', 'make', 'say', 'signal', 'sound'],
#  ['couldnt', 'figur'],
#  ['almost',
#   'could',
#   'great',
#   'not',
#   'ok',
#   'phone',
#   'said',
#   'sound',
#   'total',
#   'understand',
#   'unintellig',
#   'wife',
#   'word'],
#  ['back', 'batteri', 'phone', 'put', 'restart', 'take', 'togeth'],
#  ['back',
#   'bend',
#   'break',
#   'drop',
#   'enough',
#   'leaf',
#   'manag',
#   'metal',
#   'next',
#   'place',
#   'spring',
#   'stress'],
#  ['leopard', 'print', 'wild', 'wonder'],
#  ['work'],
#  ['floppi', 'junk', 'piec', 'saggi'],
#  ['better', 'case', 'hard', 'much', 'plastic'],
#  ['also', 'new', 'problem'],
#  ['far', 'happi'],
#  ['cool', 'phone'],
#  ['good', 'work'],
#  ['bluetooth',
#   'final',
#   'got',
#   'headset',
#   'motorola',
#   'qualiti',
#   'right',
#   'voic'],
#  ['connect', 'coupl', 'even', 'feet', 'loos', 'phone', 'two', 'within'],
#  ['great', 'realli', 'recommend', 'would'],
#  ['bluetooth', 'easier', 'keep', 'make', 'not', 'wear'],
#  ['pretti', 'said', 'useless'],
#  ['got', 'never'],
#  ['ever', 'headphon', 'pair', 'sound', 'wise', 'worst'],
#  ['[]', 'drain', 'snap', 'weak'],
#  ['att', 'charg', 'cingular', 'not', 'phone'],
#  ['call', 'carri', 'cut', 'extra', 'get', 'minut', 'not'],
#  ['black',
#   'call',
#   'could',
#   'eventu',
#   'fliptop',
#   'get',
#   'howev',
#   'loos',
#   'not',
#   'place',
#   'receiv',
#   'screen',
#   'start',
#   'went',
#   'wobbl',
#   'year'],
#  ['cabl', 'catch', 'kept', 'phone', 'pull', 'seat', 'turn'],
#  ['fulfil', 'happi', 'headset', 'purchas', 'requir'],
#  ['bluetooth', 'headset', 'logitech'],
#  ['ear', 'fact', 'insid', 'lightli', 'like', 'rather', 'rest'],
#  ['good', 'lot', 'phone', 'rate', 'websit'],
#  ['cabl', 'comput', 'fine', 'ipod', 'tri', 'work'],
#  ['joke', 'low', 'mic', 'quit', 'volum'],
#  ['return'],
#  ['comput', 'connect', 'lap', 'maintain', 'not'],
#  ['access', 'car', 'control', 'easi', 'quit', 'turn', 'volum'],
#  ['bought', 'christma', 'famili', 'mine', 'rest', 'year'],
#  ['clear', 'easi', 'instal', 'otherwis', 'sound', 'use'],
#  ['leather', 'nice'],
#  ['case', 'differ', 'purchas'],
#  ['joy', 'use'],
#  ['compani', 'disappoint', 'much'],
#  ['satisif'],
#  ['charg', 'not'],
#  ['bought', 'get', 'phone', 'sa', 'say', 'wow'],
#  ['button', 'small'],
#  ['alon', 'make', 'read', 'say', 'spec', 'wow'],
#  ['armband', 'great', 'love'],
#  ['allot',
#   'clearer',
#   'ear',
#   'like',
#   'mic',
#   'motorola',
#   'piec',
#   'product',
#   'realli'],
#  ['button', 'howev', 'keypad', 'reach', 'sometim', 'tinni', 'wrong'],
#  ['decis', 'ericson', 'exchang', 'happi', 'pretti', 'soni', 'za'],
#  ['case', 'impress', 'price'],
#  ['also', 'easier', 'hold', 'make'],
#  ['center',
#   'control',
#   'equip',
#   'great',
#   'high',
#   'hum',
#   'lot',
#   'motor',
#   'product',
#   'use',
#   'voltag',
#   'work'],
#  ['easi', 'pretti'],
#  ['call', 'cannot', 'certain', 'make', 'place'],
#  ['complain',
#   'girl',
#   'howev',
#   'like',
#   'normal',
#   'not',
#   'phone',
#   'time',
#   'wake'],
#  ['beauti', 'style', 'though'],
#  ['back',
#   'charg',
#   'compani',
#   'fee',
#   'given',
#   'not',
#   'refund',
#   'restock',
#   'still'],
#  ['refund', 'return', 'tri'],
#  ['darn', 'find', 'not', 'plug', 'thing', 'work'],
#  ['excel', 'product'],
#  ['break', 'earbud', 'easili', 'piec'],
#  ['lousi', 'product'],
#  ['abil', 'everyth', 'fail', 'hard', 'phone', 'tri'],
#  ['best', 'charger', 'market', 'seen', 'yet'],
#  ['phone', 'sweetest'],
#  ['charger', 'fine', 'oh', 'seem', 'work'],
#  ['better',
#   'canal',
#   'direct',
#   'ear',
#   'even',
#   'fit',
#   'hook',
#   'need',
#   'not',
#   'secur',
#   'sound',
#   'use'],
#  ['enough', 'not', 'volum'],
#  ['echo', 'problem', 'unsatisfactori'],
#  ['could', 'poor', 'qualiti', 'take', 'time', 'video'],
#  ['money', 'not', 'wast'],
#  ['first', 'go', 'neg', 'product', 'review'],
#  ['adapt', 'charg', 'current', 'enough', 'not', 'provid'],
#  ['assum', 'best', 'hype', 'mistak', 'much', 'phone'],
#  ['also', 'cannot', 'case', 'cover', 'lens', 'pictur', 'take'],
#  ['easili', 'fall', 'phone'],
#  ['hear', 'not', 'peopl', 'talk', 'work'],
#  ['featur', 'messag', 'realli', 'text', 'tricki', 'use'],
#  ['charger', 'disappoint', 'not', 'realli', 'work'],
#  ['ear', 'pain'],
#  ['blew', 'day', 'last', 'one'],
#  ['disappoint'],
#  ['around', 'flop', 'kind'],
#  ['ear', 'easili', 'face', 'get', 'screen', 'smudg', 'touch'],
#  ['call', 'junk', 'lose', 'phone', 'piec'],
#  ['item', 'match', 'not', 'pictur'],
#  ['disappoint', 'infra', 'irda', 'port', 'red', 'thing'],
#  ['answer', 'call', 'never', 'not', 'unit', 'work'],
#  ...]

# %% [markdown]
# ##**Pregunta - 6:**

# %% [markdown]
# En esta pregunta deberás generar la nube de palabras de cada clase: la de los comentarios positivos y la de los comentarios negativos.
#
# En la primera parte de esta pregunta y a partir del conjunto de comentarios obtenido hasta ahora, Xclean, deberás obtener el string de comentarios positivos llamada "pt" y el de comentarios negativos "nt".
#
# En la parte 2 deberás mostrar las dos nubes de palabras: la nube de palabras de los comentarios positivos y la nube de palabras de los comentarios negativos.
#
# En la parte 3 de este ejercicio deberás incluir tus comentarios de lo que observas de ambas nubes de palabras.
#
# Igualmente deberás incluir los paquetes o librerías necesarios.

# %%
##############################################################################
# AGREGA AQUÍ TUS LÍNEAS DE CÓDIGO - Pregunta 6 - parte 1:

arr = np.array(Xclean, dtype = 'object')

pt = arr[Y.to_numpy() == 1]
nt = arr[Y.to_numpy() == 0]

print(f"Tamaño comentarios positivos: {pt.size} y tamaño comentarios negativos {nt.size}")

# FIN PARA AGREGAR TUS LÍNEAS DE CÓDIGO.
##############################################################################
# Out:
# Tamaño comentarios positivos: 1500 y tamaño comentarios negativos 1500

# %%
##############################################################################
# AGREGA AQUÍ TUS LÍNEAS DE CÓDIGO - Pregunta 6 - parte 2:


from wordcloud import WordCloud
from matplotlib import pyplot as plt 

tokens = [pt, nt]

for token in tokens:
    wc_text = ''

    for txt in token:

        wc_text = wc_text +" " + " ".join(txt)
    
    wc = WordCloud(background_color='white').generate(wc_text)

#plot the wordcloud
    plt.figure(figsize = (12, 12))
    plt.imshow(wc)

#to remove the axis value
    plt.axis("off")
    plt.show()


# FIN PARA AGREGAR TUS LÍNEAS DE CÓDIGO.
##############################################################################

# %% [markdown]
# ######################################################################
# ###### **AGREGA AQUÍ TUS COMENTARIOS - Pregunta 6 - parte 3:**
#
#
# None
#
#
# ###### **FIN PARA AGREGAR TUS COMENTARIOS.**
# ######################################################################

# %% [markdown]
# ###**Train-Validation-Test**
#
# Para este ejercicio realizaremos una partición de train-validation-test del 70%-15%-15%, respectivamente.
#
# Obviamente la distribución de esta partición puede ser otro de los hiperparámetros a determinar, pero para fines de este ejercicio consideraremos dichos valores.

# %%
from sklearn.model_selection import train_test_split

x_train, x_val_and_test, y_train, y_val_and_test = train_test_split(Xclean, Y, train_size=.70, shuffle=True, random_state=1) 
x_val, x_test, y_val, y_test = train_test_split(x_val_and_test, y_val_and_test, test_size=.50, shuffle=True, random_state=17)

print('X,y Train:', len(x_train), len(y_train))      # los "x_" son "list" y los "y_" son "Series"
print('X,y Val:', len(x_val), len(y_val))
print('X,y Test', len(x_test), len(y_test))
# Out:
# X,y Train: 2100 2100
# X,y Val: 450 450
# X,y Test 450 450

# %% [markdown]
# ###Construyamos a continuación nuestro vocabulario de palabras con base al conteo de tokens/palabras del conjunto de entrenamiento.

# %%
from collections import Counter

# %%
midiccionario = Counter()    

for k in range(len(x_train)):
  midiccionario.update(x_train[k])


print('Longitud del diccionario:', len(midiccionario))  
print('\n(word,frequency):') 
print(midiccionario.most_common(10))
# Out:
# Longitud del diccionario: 3179
#
# (word,frequency):
# [('not', 344), ('good', 157), ('movi', 135), ('great', 133), ('film', 125), ('phone', 125), ('work', 112), ('time', 102), ('like', 94), ('one', 94)]

# %%
# Veamos la gráfica de palabras nuestro diccionario con base a la frecuencia de las palabras/tokens:

plt.plot(list(np.arange(len(midiccionario))), list(midiccionario.values()), color='blue')
plt.show()

# %% [markdown]
# ###Descartemos palabras cuya frecuencia en el conjunto de entrenamiento es muy pequeña:

# %% [markdown]
# ##**Pregunta - 7:**

# %% [markdown]
# En esta pregunta deberás determinar la frecuencia mínima de aparición de los tokens del diccionario/vocabulario en el conjunto de entrenamiento. Es usual que al menos se filtren los tokens de frecuencia 1, ya que usualmente no dan mayor información.
#
# Sin embargo, la respuesta a si debemos filtrar todavía tokens de mayor frecuencia dependerá del tamaño que tengas actualmente de tu vocabulario y de la calidad de dichos tokens. Una manera de determinar dicha calidad de los tokens es con el resultado de los modelos de aprendizaje (regresión logística, random-forest, etc.) que aplicarás en los ejercicios de la última parte de esta Actividad.
#
# Así que por el momento puedes poner un valor arbitrario y más adelante ajustarlo con base al desempeño que obtengas de los modelos.
#
# Sin embargo, debes cuidar que la frecuencia de los tokens no la consideres demasiado grande, que empieces a generar una gran cantidad de comentarios vacíos en tu conjunto de entrenamiento.
#
# Llamaremos "min_freq" a la frecuencia mínima de aparición de un token para considerarlo dentro del vocabulario/diccionario. Debe ser un número entero.
#
# Llamaremos "midicc" al nuevo diccionario que generes con tokens de frecuencia natural (es decir, de conteo) mayor o igual a "min_freq".

# %%
##############################################################################
# AGREGA AQUÍ TUS LÍNEAS DE CÓDIGO - Pregunta 7:

min_freq = None

midicc = None


# FIN PARA AGREGAR TUS LÍNEAS DE CÓDIGO.
##############################################################################

print('Nueva longitud del nuevo vocabulario:', len(midicc))
print(list(midicc.items())[0:5])     # veamos algunos elementos del diccionario.

# %% [markdown]
# ###Filtremos los conjuntos Train, Validation y Test con respecto al nuevo vocabulario propuesto:

# %%
train_x = []
for ss in x_train:
  train_x.append([w for w in ss if w in midicc])

val_x = []
for ss in x_val:
  val_x.append([w for w in ss if w in midicc])

test_x = []
for ss in x_test:
  test_x.append([w for w in ss if w in midicc])

# %%
# Podemos ver algunos de los comentarios de entrenamiento, antes y después 
# de incluir la condición de la frecuencia mínima de ocurrencia de un token:

for k in range(3):
  print('Antes:', x_train[k])
  print('Después:', train_x[k])

# %% [markdown]
# ###Obtengamos las matrices de conteo document-term-matrix como matrices dispersas (sparse matrices ). Para ello requerimos que cada comentario esté como un solo string.

# %%
train_x_docs = []
for k in range(len(train_x)):
  train_x_docs.append(' '.join(train_x[k]))

val_x_docs = []
for k in range(len(val_x)):
  val_x_docs.append(' '.join(val_x[k]))

test_x_docs = []
for k in range(len(test_x)):
  test_x_docs.append(' '.join(test_x[k]))



# Verifica que los primeros comentarios de Train están cada uno como un solo string:
for k in range(3):
  print(train_x_docs[k])

# %% [markdown]
# ###Ahora generemos las matrices sparse en su formato predeterminado CSR de estas matrices de conteo:

# %%
mivocab = list(midicc.keys())     # Obtenemos nuestro vocabulario de tokens/palabras.

#mivocab.sort()    # Usualmente se ordenan alfabéticamente, pero para visualizar algunos de los valores 
                   # no cero de las matrices, por el momento no lo haremos.



# Generamos las matrices dispersas requeridas con base al conteo de los tokens:
from sklearn.feature_extraction.text import CountVectorizer

countvectorizer = CountVectorizer(vocabulary=mivocab)
train_x_count = countvectorizer.fit_transform(train_x_docs)     
val_x_count = countvectorizer.transform(val_x_docs) 
test_x_count = countvectorizer.transform(test_x_docs)

count_tokens = countvectorizer.get_feature_names_out()
df_countvect = pd.DataFrame(data = train_x_count.toarray(),  columns = count_tokens)  
print(df_countvect.iloc[0:3,6:18])   # veamos las frecuencias de los primeros comentarios.

# %%
p_sparse = 1 - train_x_count.count_nonzero() / (train_x_count.shape[0] * train_x_count.shape[1])    # Sparsity : Porcentaje de valores de 0.
print('Porcentaje de valores cero de la matriz sparse de entrenamiento: %.1f%%' % (100*p_sparse))

# %% [markdown]
# ##**Pregunta - 8:**

# %% [markdown]
# En este ejercicio deberás ahora generar las matrices dispersas TF-IDF para los conjuntos de entrenamiento, validación y prueba.
#
# Deberás usar el vocabulario "mivocab" para generar dichas matrices.
#
# Dichas matrices las llamaremos "train_x_tfidf", "val_x_tfidf" y "test_x_tfidf".
#
# Deberás agregar además las librerías o módulos necesarios.
#
# Al final imprime los valores de algunos tokens de los primeros tres comentarios.

# %%
##############################################################################
# AGREGA AQUÍ TUS LÍNEAS DE CÓDIGO - Pregunta 8:



None



# FIN PARA AGREGAR TUS LÍNEAS DE CÓDIGO.
##############################################################################

# %% [markdown]
# ##**Pregunta - 9:**

# %% [markdown]
# ###A continuación, usando Sklearn, deberás aplicar los modelos de regresión logística (lo llamaremos modeloLRcount), ranfom-forest para clasificación (lo llamaremos modeloRFcount) y naive-bayes en su opción MultinomialNB (lo llamaremos modeloNBcount).
#
# ###Deberás de utilizar las matrices de conteo "train_x_count", "val_x_count" y "test_x_count".
#
# ###Con el mejor modelo obtenido, se usará el conjunto de prueba (test) para obtener el desempeño (Accuracy) final y su matriz de confusión.
#
# ###Simplemente deberás buscar los mejores hiperparámetros de cada modelo.
#
# ###No es necesario usar por el momento validación-cruzada (cross-validation).
#
# ###Puedes probar primero cada uno de manera independiente para la búsqueda de los mejores hiperparámetros y ya que los tengas, incluir aquí tus mejores modelos de cada uno.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB

# %%
##############################################################################
# AGREGA AQUÍ TUS LÍNEAS DE CÓDIGO - Pregunta 9:


modeloLRcount = None



modeloRFcount = None




modeloNBcount = None





# FIN PARA AGREGAR TUS LÍNEAS DE CÓDIGO.
##############################################################################


print('LR: Train-accuracy: %.2f%%' % (100*modeloLRcount.score(train_x_count, y_train)))
print('LR: Val-accuracy: %2.f%%' % (100*modeloLRcount.score(val_x_count, y_val)))

print('\nRF: Train-accuracy: %.2f%%' % (100*modeloRFcount.score(train_x_count, y_train)))
print('RF: Val-accuracy: %.2f%%' % (100*modeloRFcount.score(val_x_count, y_val)))

print('\nNB: Train-accuracy: %.2f%%' % (100*modeloNBcount.score(train_x_count, y_train)))
print('NB: Val-accuracy: %.2f%%' % (100*modeloNBcount.score(val_x_count, y_val)))

# %%
##############################################################################
# AGREGA AQUÍ EL NOMBRE DE TU MEJOR MODELO OBTENIDO CON COUNTER:

mejor_modelo_Count = None # incluye el nombre, modeloXXcount, de tu mejor modelo.

# FIN PARA AGREGAR TUS LÍNEAS DE CÓDIGO.
##############################################################################



print('Test-accuracy con el mejor modelo de Conteo %.2f%%' % (100*mejor_modelo_Count.score(test_x_count, y_test)))

from sklearn.metrics import confusion_matrix

pred = mejor_modelo_Count.predict(test_x_count)
print('\nMatriz de confusión con el mejor modelo de Conteo:')
print(confusion_matrix(y_test, pred, labels=[0,1]))

print('\nMatriz de confusión con el mejor modelo de Conteo en proporciones:')
print(confusion_matrix(y_test, pred, labels=[0,1]) / pred.shape[0])

# %% [markdown]
# ##**Pregunta - 10:**

# %% [markdown]
# ###Deberás repetir el ejercicio anterior, pero usando ahora las matrices TF-IDF obtenidas previamente: "train_x_tfidf", "val_x_tfidf" y "test_x_tfidf".
#
# ###Llamaremos a los modelos modeloXXtfidf, para LR, RF y NB.

# %%
##############################################################################
# AGREGA AQUÍ TUS LÍNEAS DE CÓDIGO - Pregunta 10:


modeloLRtfidf = None



modeloRFtfidf = None




modeloNBtfidf = None





# FIN PARA AGREGAR TUS LÍNEAS DE CÓDIGO.
##############################################################################


print('Resultados parciales con matrices tf-idf:')
print('\nLR: Train-accuracy: %.2f%%' % (100*modeloLRtfidf.score(train_x_tfidf, y_train)))
print('LR: Val-accuracy: %2.f%%' % (100*modeloLRtfidf.score(val_x_tfidf, y_val)))

print('\nRF: Train-accuracy: %.2f%%' % (100*modeloRFtfidf.score(train_x_tfidf, y_train)))
print('RF: Val-accuracy: %.2f%%' % (100*modeloRFtfidf.score(val_x_tfidf, y_val)))

print('\nNB: Train-accuracy: %.2f%%' % (100*modeloNBtfidf.score(train_x_tfidf, y_train)))
print('NB: Val-accuracy: %.2f%%' % (100*modeloNBtfidf.score(val_x_tfidf, y_val)))

# %%
##############################################################################
# AGREGA AQUÍ EL NOMBRE DE TU MEJOR MODELO OBTENIDO CON TF-IDF:

mejor_modelo_Tfidf = None # incluye el nombre, modeloXXtfidf, de tu mejor modelo.

# FIN PARA AGREGAR TUS LÍNEAS DE CÓDIGO.
##############################################################################



print('Test-accuracy con el mejor modelo Tf-idf %.2f%%' % (100*mejor_modelo_Tfidf.score(test_x_tfidf, y_test)))

pred = mejor_modelo_Tfidf.predict(test_x_tfidf)
print('\nMatriz de confusión con el mejor modelo Tf-idf:')
print(confusion_matrix(y_test, pred, labels=[0,1]))

print('\nMatriz de confusión con el mejor modelo de Tf-idf en proporciones:')
print(confusion_matrix(y_test, pred, labels=[0,1]) / pred.shape[0])

# %% [markdown]
# ##**Pregunta - 11:**

# %% [markdown]
# ###Finalmente incluye tus conclusiones finales de la Actividad.
#
# ###En particular, indica cuál técnica resultó mejor en este problema, ¿usando matrices de conteo o tf-idf?
#
# ###Indica también a qué crees que se debe la diferencia entre los valores de los Falsos-Negativos y Falsos-Positivos de la mejor matriz de confusión que obtuviste. ¿Qué implicaciones podrían tener cada uno de estos errores?
#
# ##**Como nota complementaria, se esperaría que tu mejor modelo final mínimamente debiera alcanzar un 72% de buen desempeño (accuracy), pero puede ser mayor.**

# %% [markdown]
# ######################################################################
# ###### **AGREGA AQUÍ TUS CONCLUSIONES FINALES - Pregunta 11:**
#
#
# None
#
#
# ###### **FIN PARA AGREGAR TUS CONCLUSIONES FINALES.**
# ######################################################################

# %% [markdown]
# #**FIN DE LA ACTIVIDAD DE LAS SEMANAS 3 Y 4**
